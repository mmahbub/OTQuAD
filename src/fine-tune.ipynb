# %%
# !python3 load_dataset.py  \
#     --orig_model_name_or_path biobert-v1.1  \
#     --model_name_or_path dmis-lab/biobert-base-cased-v1.1  \
#     --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
#     --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/bioasq/BioASQ-8b/  \
#     --predict_file test_bioasq_8b-3.json  \
#     --dataset_name bioasq_8b_3  \
#     --do_evaluate \
#     --max_seq_length 384   \
#     --doc_stride 128  \
#     --overwrite_cache

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path bert-base-uncased  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_train \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_train_batch_size 12 \
    --num_train_epochs 100.0 \
    --learning_rate  5e-5  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir
# Out:
# /home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ^C
# Traceback (most recent call last):
#   File "finetune_model.py", line 8, in <module>
#     from src.load_dataset import load_and_cache_examples
#   File "../src/load_dataset.py", line 14, in <module>
#     import transformers
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/transformers/__init__.py", line 22, in <module>
#     from .integrations import (  # isort:skip
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/transformers/integrations.py", line 58, in <module>
#     from .file_utils import is_torch_tpu_available
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/transformers/file_utils.py", line 59, in <module>
#     import tensorflow as tf
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py", line 41, in <module>
#     from tensorflow._api.v1 import compat
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/_api/v1/compat/__init__.py", line 21, in <module>
#     from tensorflow._api.v1.compat import v1
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow/_api/v1/compat/v1/__init__.py", line 649, in <module>
#     from tensorflow_estimator.python.estimator.api._v1 import estimator
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/__init__.py", line 8, in <module>
#     from tensorflow_estimator._api.v1 import estimator
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/_api/v1/estimator/__init__.py", line 8, in <module>
#     from tensorflow_estimator._api.v1.estimator import experimental
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/_api/v1/estimator/experimental/__init__.py", line 8, in <module>
#     from tensorflow_estimator.python.estimator.canned.dnn import dnn_logit_fn_builder
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/__init__.py", line 25, in <module>
#     import tensorflow_estimator.python.estimator.estimator_lib
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/estimator_lib.py", line 53, in <module>
#     from tensorflow_estimator.python.estimator.inputs import inputs
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/inputs.py", line 22, in <module>
#     from tensorflow_estimator.python.estimator.inputs.numpy_io import numpy_input_fn
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/numpy_io.py", line 26, in <module>
#     from tensorflow_estimator.python.estimator.inputs.queues import feeding_functions
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/tensorflow_estimator/python/estimator/inputs/queues/feeding_functions.py", line 40, in <module>
#     import pandas as pd
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/pandas/__init__.py", line 52, in <module>
#     from pandas.core.api import (
#   File "/home/maria/anaconda3/lib/python3.7/site-packages/pandas/core/api.py", line 6, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 677, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 818, in get_code
#   File "<frozen importlib._bootstrap_external>", line 917, in get_data
# KeyboardInterrupt

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased-squad-v1.1  \
    --model_name_or_path csarron/bert-base-uncased-squad-v1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_train \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_train_batch_size 12 \
    --num_train_epochs 100.0 \
    --learning_rate  5e-5  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir \
    --overwrite_cache
# Out:
# 12/07/2021 23:32:37 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2021-12-07 23:32:37,515 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2021-12-07 23:32:37,517 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|configuration_utils.py:530] 2021-12-07 23:32:37,765 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2021-12-07 23:32:37,766 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1717] 2021-12-07 23:32:38,406 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/d1151882521c5317bfebfc93bbab1266ec34c0f92ca2b03d9d2661905be15ab1.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1717] 2021-12-07 23:32:38,406 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2021-12-07 23:32:38,406 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/special_tokens_map.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/c1d618b70fc6898914e51fe9281c26e67b5c171dec2bf45f76e01124df96cbb6.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# [INFO|tokenization_utils_base.py:1717] 2021-12-07 23:32:38,406 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/tokenizer_config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/aa051bd945f38953e3bb49399e953855a5dde0fc46dd93899607162698cbdb63.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# [INFO|tokenization_utils_base.py:1717] 2021-12-07 23:32:38,406 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/tokenizer.json from cache at None
# [INFO|modeling_utils.py:1161] 2021-12-07 23:32:38,598 >> loading weights file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/cc49866c357ded9e5e5047656847944e31b4fdbac69bd2ddd8567352acac8973.9113a3a907fc5caecafe526ef30b1b18dd4dcc741d60cb2080ae038c9b3b0cba
# [INFO|modeling_utils.py:1345] 2021-12-07 23:32:39,684 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2021-12-07 23:32:39,684 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at csarron/bert-base-uncased-squad-v1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 12/07/2021 23:32:42 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=5e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='csarron/bert-base-uncased-squad-v1', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=100.0, orig_model_name_or_path='bert-base-uncased-squad-v1.1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/', overwrite_cache=True, overwrite_output_dir=True, overwrite_output_model_dir=True, per_gpu_eval_batch_size=24, per_gpu_train_batch_size=12, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file='train_otquad.json', verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 12/07/2021 23:32:42 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased-squad-v1.1_384_train_otquad
# 100%|███████████████████████████████████████| 417/417 [00:00<00:00, 2234.88it/s]
# convert squad examples to features: 100%|█████| 417/417 [00:05<00:00, 71.00it/s]
# add example index and unique id: 100%|████| 417/417 [00:00<00:00, 330628.50it/s]
# 12/07/2021 23:32:48 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:32:49 - INFO - __main__ - ***** Running training *****
# 12/07/2021 23:32:49 - INFO - __main__ -   Num examples = 607
# 12/07/2021 23:32:49 - INFO - __main__ -   Num Epochs = 100
# 12/07/2021 23:32:49 - INFO - __main__ -   Instantaneous batch size per GPU = 12
# 12/07/2021 23:32:49 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 48
# 12/07/2021 23:32:49 - INFO - __main__ -   Gradient Accumulation steps = 1
# 12/07/2021 23:32:49 - INFO - __main__ -   Total optimization steps = 1300
# Epoch:   0%|                                            | 0/100 [00:00<?, ?it/s]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]/net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:65: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#
# Iteration:   8%|██▌                              | 1/13 [00:10<02:07, 10.63s/it]
# Iteration:  15%|█████                            | 2/13 [00:10<01:23,  7.55s/it]
# Iteration:  23%|███████▌                         | 3/13 [00:11<00:53,  5.38s/it]
# Iteration:  31%|██████████▏                      | 4/13 [00:11<00:34,  3.86s/it]
# Iteration:  38%|████████████▋                    | 5/13 [00:11<00:22,  2.80s/it]
# Iteration:  46%|███████████████▏                 | 6/13 [00:12<00:14,  2.06s/it]
# Iteration:  54%|█████████████████▊               | 7/13 [00:12<00:09,  1.53s/it]
# Iteration:  62%|████████████████████▎            | 8/13 [00:12<00:05,  1.17s/it]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:13<00:03,  1.09it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:13<00:02,  1.35it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:13<00:01,  1.63it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:14<00:00,  1.91it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:14<00:00,  1.11s/it]
# 12/07/2021 23:33:03 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2844.95it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:46,  2.71it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.83it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.37it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 100.50it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 313409.76it/s]
# 12/07/2021 23:33:05 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:05 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:05 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:05 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  2.52it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  3.18it/s]
# 12/07/2021 23:33:05 - INFO - __main__ -   Evaluation done in total 0.629222 secs (0.004916 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:05,927 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:05,927 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   1%|▎                                   | 1/100 [00:17<28:36, 17.34s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:06,  1.99it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:05,  2.18it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:04,  2.33it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.44it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:03,  2.55it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.62it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.68it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.72it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.76it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.78it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:04<00:00,  2.79it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.80it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.77it/s]
# 12/07/2021 23:33:11 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1566.47it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.65it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.75it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:12,  5.25it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 94.48it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 333874.95it/s]
# 12/07/2021 23:33:12 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:13 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:13 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:13 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.43it/s]
# 12/07/2021 23:33:13 - INFO - __main__ -   Evaluation done in total 0.311450 secs (0.002433 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:13,374 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:13,374 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   2%|▋                                   | 2/100 [00:24<23:27, 14.36s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.91it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.89it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.68it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.72it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.75it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.77it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.78it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.79it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.80it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.80it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.81it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.82it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.82it/s]
# 12/07/2021 23:33:18 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1568.60it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.69it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.81it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.35it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 100.44it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 283159.76it/s]
# 12/07/2021 23:33:20 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:20 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:20 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:20 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.39it/s]
# 12/07/2021 23:33:20 - INFO - __main__ -   Evaluation done in total 0.313637 secs (0.002450 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:20,623 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:20,623 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   3%|█                                   | 3/100 [00:31<19:45, 12.22s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.88it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.79it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.77it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.79it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:03,  2.53it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.62it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.73it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.83it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.90it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.97it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.95it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.97it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.89it/s]
# 12/07/2021 23:33:25 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2962.70it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:48,  2.64it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.74it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:12,  5.24it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 95.15it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 319946.91it/s]
# 12/07/2021 23:33:27 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:27 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:27 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:27 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.32it/s]
# 12/07/2021 23:33:27 - INFO - __main__ -   Evaluation done in total 0.316901 secs (0.002476 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:27,766 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:27,766 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   4%|█▍                                  | 4/100 [00:39<17:06, 10.70s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:03,  3.06it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  3.01it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  3.00it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  3.00it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.98it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.95it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.91it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.89it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.93it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.97it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.67it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.74it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.92it/s]
# 12/07/2021 23:33:32 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2321.30it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:53,  2.38it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:28,  3.37it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:13,  4.73it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 94.13it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 294984.02it/s]
# 12/07/2021 23:33:34 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:34 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:34 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:34 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.36it/s]
# 12/07/2021 23:33:34 - INFO - __main__ -   Evaluation done in total 0.315205 secs (0.002463 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:34,895 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:34,895 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   5%|█▊                                  | 5/100 [00:46<15:15,  9.63s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.86it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.82it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.81it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.81it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.81it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.82it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.82it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.82it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.82it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.80it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.79it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.51it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.76it/s]
# 12/07/2021 23:33:40 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1575.28it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:46,  2.74it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.87it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.37it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 84.62it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 302974.56it/s]
# 12/07/2021 23:33:41 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:42 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:42 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:42 - INFO - __main__ -   Batch size = 96
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.39it/s]
# 12/07/2021 23:33:42 - INFO - __main__ -   Evaluation done in total 0.313275 secs (0.002447 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:42,512 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:42,513 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   6%|██▏                                 | 6/100 [00:53<14:08,  9.03s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.91it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.88it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.86it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.84it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.84it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.83it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.82it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.79it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.79it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.78it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.78it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.79it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.84it/s]
# 12/07/2021 23:33:47 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1575.03it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.70it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.82it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.35it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 100.26it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 298261.62it/s]
# 12/07/2021 23:33:49 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:49 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:49 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:49 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.75it/s]
# 12/07/2021 23:33:49 - INFO - __main__ -   Evaluation done in total 0.421405 secs (0.003292 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:49,819 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:49,819 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   7%|██▌                                 | 7/100 [01:01<13:11,  8.51s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.87it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.85it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.84it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.83it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.83it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.81it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.82it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.82it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.82it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.81it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.78it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.77it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.84it/s]
# 12/07/2021 23:33:54 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1572.74it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:46,  2.71it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.83it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.38it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 100.36it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 281084.25it/s]
# 12/07/2021 23:33:56 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:33:56 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:33:56 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:33:56 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.28it/s]
# 12/07/2021 23:33:57 - INFO - __main__ -   Evaluation done in total 0.379584 secs (0.002965 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:33:57,058 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:33:57,058 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   8%|██▉                                 | 8/100 [01:08<12:28,  8.13s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.89it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.87it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.85it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.84it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.84it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.83it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.82it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.82it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.80it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.80it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.80it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.81it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.86it/s]
# 12/07/2021 23:34:02 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1571.26it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.69it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.81it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.35it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 100.52it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 320711.42it/s]
# 12/07/2021 23:34:03 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:34:03 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:34:03 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:34:03 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.34it/s]
# 12/07/2021 23:34:04 - INFO - __main__ -   Evaluation done in total 0.315719 secs (0.002467 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:34:04,225 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:34:04,225 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   9%|███▏                                | 9/100 [01:15<11:51,  7.82s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:03,  3.05it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.82it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.84it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.83it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.86it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.89it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.94it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.96it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.97it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.96it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.91it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.91it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.95it/s]
# 12/07/2021 23:34:09 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2827.12it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:43,  2.90it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:23,  4.09it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.72it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 97.78it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 327960.24it/s]
# 12/07/2021 23:34:10 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:34:10 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:34:10 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:34:10 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.43it/s]
# 12/07/2021 23:34:11 - INFO - __main__ -   Evaluation done in total 0.311386 secs (0.002433 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:34:11,235 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:34:11,235 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  10%|███▌                               | 10/100 [01:22<11:22,  7.58s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:03,  3.08it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.86it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.89it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.90it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.90it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.89it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.87it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.85it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.84it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.88it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.93it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.95it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.93it/s]
# 12/07/2021 23:34:16 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1723.49it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:48,  2.64it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.73it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:12,  5.23it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 95.12it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 330789.22it/s]
# 12/07/2021 23:34:17 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:34:18 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:34:18 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:34:18 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.39it/s]
# 12/07/2021 23:34:18 - INFO - __main__ -   Evaluation done in total 0.313250 secs (0.002447 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:34:18,321 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:34:18,321 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  11%|███▊                               | 11/100 [01:29<11:01,  7.43s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.92it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.92it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.91it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.90it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.92it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.90it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.90it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.71it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.81it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.88it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.91it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.92it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.95it/s]
# 12/07/2021 23:34:23 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2893.57it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.66it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.77it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.28it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 95.61it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 308901.56it/s]
# 12/07/2021 23:34:24 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:34:25 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:34:25 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:34:25 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.41it/s]
# 12/07/2021 23:34:25 - INFO - __main__ -   Evaluation done in total 0.312619 secs (0.002442 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:34:25,337 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:34:25,338 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  12%|████▏                              | 12/100 [01:36<10:42,  7.30s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:03,  3.12it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  3.12it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:00<00:03,  3.12it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:02,  3.12it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  3.12it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:01<00:02,  3.12it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:01,  3.13it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  3.13it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:02<00:01,  3.13it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:00,  3.14it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.91it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:03<00:00,  2.99it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  3.13it/s]
# 12/07/2021 23:34:29 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2792.99it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.66it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.77it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.25it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 88.88it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 305735.14it/s]
# 12/07/2021 23:34:31 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:34:31 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:34:31 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:34:31 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.32it/s]
# 12/07/2021 23:34:32 - INFO - __main__ -   Evaluation done in total 0.316862 secs (0.002475 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:34:32,200 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:34:32,200 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  13%|████▌                              | 13/100 [01:43<10:27,  7.21s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.88it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.86it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.87it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.88it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.88it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.87it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.86it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.84it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.82it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.83it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.85it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.86it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.85it/s]
# 12/07/2021 23:34:37 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1594.95it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.67it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.78it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.29it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 95.41it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 310869.09it/s]
# 12/07/2021 23:34:38 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:34:39 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:34:39 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:34:39 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.32it/s]
# 12/07/2021 23:34:39 - INFO - __main__ -   Evaluation done in total 0.317033 secs (0.002477 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:34:39,543 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# ...
# 12/07/2021 23:44:43 - INFO - __main__ -   Evaluation done in total 0.315468 secs (0.002465 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:44:43,075 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:44:43,076 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  98%|██████████████████████████████████▎| 98/100 [11:54<00:14,  7.25s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.88it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.87it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.85it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.85it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.84it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.83it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.83it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.58it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.62it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.65it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:04<00:00,  2.70it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.73it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.78it/s]
# 12/07/2021 23:44:48 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 1551.81it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:47,  2.69it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:24,  3.80it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:11,  5.33it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 101.15it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 300936.61it/s]
# 12/07/2021 23:44:49 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:44:50 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:44:50 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:44:50 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.55it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.21it/s]
# 12/07/2021 23:44:50 - INFO - __main__ -   Evaluation done in total 0.322510 secs (0.002520 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:44:50,368 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:44:50,369 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  99%|██████████████████████████████████▋| 99/100 [12:01<00:07,  7.25s/it]
# Iteration:   0%|                                         | 0/13 [00:00<?, ?it/s]
# Iteration:   8%|██▌                              | 1/13 [00:00<00:04,  2.91it/s]
# Iteration:  15%|█████                            | 2/13 [00:00<00:03,  2.89it/s]
# Iteration:  23%|███████▌                         | 3/13 [00:01<00:03,  2.89it/s]
# Iteration:  31%|██████████▏                      | 4/13 [00:01<00:03,  2.88it/s]
# Iteration:  38%|████████████▋                    | 5/13 [00:01<00:02,  2.86it/s]
# Iteration:  46%|███████████████▏                 | 6/13 [00:02<00:02,  2.88it/s]
# Iteration:  54%|█████████████████▊               | 7/13 [00:02<00:02,  2.88it/s]
# Iteration:  62%|████████████████████▎            | 8/13 [00:02<00:01,  2.86it/s]
# Iteration:  69%|██████████████████████▊          | 9/13 [00:03<00:01,  2.85it/s]
# Iteration:  77%|████████████████████████▌       | 10/13 [00:03<00:01,  2.83it/s]
# Iteration:  85%|███████████████████████████     | 11/13 [00:03<00:00,  2.81it/s]
# Iteration:  92%|█████████████████████████████▌  | 12/13 [00:04<00:00,  2.79it/s]
# Iteration: 100%|████████████████████████████████| 13/13 [00:04<00:00,  2.83it/s]
# 12/07/2021 23:44:55 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
#
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2056.09it/s]
#
# convert squad examples to features:   0%|               | 0/128 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/128 [00:00<00:48,  2.60it/s]
# convert squad examples to features:  26%|█▌    | 33/128 [00:00<00:25,  3.68it/s]
# convert squad examples to features:  51%|███   | 65/128 [00:01<00:12,  5.15it/s]
# convert squad examples to features: 100%|█████| 128/128 [00:01<00:00, 95.65it/s]
#
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 314327.23it/s]
# 12/07/2021 23:44:57 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:44:57 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:44:57 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:44:57 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.38it/s]
# 12/07/2021 23:44:57 - INFO - __main__ -   Evaluation done in total 0.313830 secs (0.002452 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:44:57,608 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:44:57,608 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch: 100%|██████████████████████████████████| 100/100 [12:08<00:00,  7.29s/it]
# [66.40625, 69.53125, 64.84375, 63.28125, 67.96875, 65.625, 65.625, 62.5, 67.1875, 67.96875, 69.53125, 64.84375, 64.0625, 64.0625, 64.0625, 64.0625, 63.28125, 62.5, 62.5, 64.0625, 61.71875, 64.84375, 60.9375, 64.0625, 63.28125, 65.625, 61.71875, 64.0625, 64.84375, 64.84375, 65.625, 64.0625, 65.625, 62.5, 65.625, 65.625, 66.40625, 61.71875, 65.625, 64.84375, 67.1875, 64.84375, 62.5, 64.0625, 62.5, 62.5, 64.84375, 64.0625, 62.5, 62.5, 62.5, 62.5, 60.15625, 60.9375, 60.15625, 60.9375, 60.9375, 60.9375, 61.71875, 61.71875, 62.5, 64.0625, 64.84375, 64.0625, 64.0625, 64.0625, 63.28125, 63.28125, 63.28125, 63.28125, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 62.5, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 64.0625, 64.0625, 64.0625, 64.0625, 64.0625, 64.0625, 64.0625, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125, 63.28125] [83.60432514934982, 85.38061156852275, 82.65978049171187, 82.94342511084194, 85.956337097999, 85.2101877094797, 84.20099475710624, 82.42093197897381, 85.40175118502634, 85.0090042488951, 86.78314613405672, 82.2023476688373, 83.24206098114277, 82.3517894657372, 81.57114440006995, 82.39835690560531, 82.91150379475928, 83.05836088063356, 82.60367357811394, 82.1412178974294, 82.52588431997312, 83.85142328640316, 81.2192631443185, 84.71289688225177, 83.92328055495162, 85.59782639310039, 84.92072211245146, 84.44925768533446, 84.19796825814049, 84.28572232925056, 84.52443760702833, 84.5210408678979, 85.47280717224572, 83.6592740877906, 85.09878238273222, 84.5624570961607, 83.76015010203191, 82.68608682936767, 84.61430054988837, 84.61566798029136, 85.61499320113052, 85.31236042161345, 84.41010341373783, 85.03146096228737, 84.51339255704067, 84.58779731894543, 85.11607112846924, 85.13294235654517, 83.9418180702922, 84.0591362141049, 83.97092785383771, 84.3895208906793, 83.59881888303589, 84.10288059410888, 83.56889599815138, 84.14092235142773, 84.09277809372465, 84.50062334389366, 84.29973048675082, 84.16952215341747, 84.05461170965528, 84.2609887108868, 84.41723871088682, 84.4520209495208, 84.90840249501935, 84.90840249501935, 84.8275835295021, 84.8275835295021, 84.8275835295021, 84.99257410146943, 84.73215743480276, 84.73215743480276, 84.60194910146943, 84.75695902210434, 84.75695902210434, 84.49938326452859, 84.49938326452859, 84.75979993119526, 84.75979993119526, 85.01737568877101, 85.01737568877101, 85.01737568877101, 85.01737568877101, 85.23034584059987, 85.23034584059987, 85.23034584059987, 84.99757167032568, 84.99757167032568, 84.99757167032568, 84.99757167032568, 84.73715500365901, 84.73715500365901, 84.71235341635743, 84.71235341635743, 84.71235341635743, 84.71235341635743, 84.71235341635743, 84.9699291739332, 84.9699291739332, 84.9699291739332]
# 12/07/2021 23:44:58 - INFO - __main__ -  global_step = 1301, average loss = 0.03835368379785221
# 12/07/2021 23:44:58 - INFO - __main__ - Saving model checkpoint to /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/
# [INFO|configuration_utils.py:364] 2021-12-07 23:44:59,911 >> Configuration saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|modeling_utils.py:898] 2021-12-07 23:45:01,586 >> Model weights saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|tokenization_utils_base.py:1948] 2021-12-07 23:45:01,590 >> tokenizer config file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1954] 2021-12-07 23:45:01,594 >> Special tokens file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/special_tokens_map.json
# [INFO|configuration_utils.py:528] 2021-12-07 23:45:01,630 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2021-12-07 23:45:01,630 >> Model config BertConfig {
#   "_name_or_path": "csarron/bert-base-uncased-squad-v1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2021-12-07 23:45:01,631 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2021-12-07 23:45:02,594 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2021-12-07 23:45:02,594 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# [INFO|tokenization_utils_base.py:1651] 2021-12-07 23:45:02,597 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2021-12-07 23:45:02,597 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2021-12-07 23:45:02,597 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2021-12-07 23:45:02,597 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2021-12-07 23:45:02,597 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2021-12-07 23:45:02,597 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2021-12-07 23:45:02,597 >> loading file None
# 12/07/2021 23:45:02 - INFO - __main__ - Loading checkpoints saved during training for evaluation
# 12/07/2021 23:45:02 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/']
# [INFO|configuration_utils.py:528] 2021-12-07 23:45:02,728 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2021-12-07 23:45:02,729 >> Model config BertConfig {
#   "_name_or_path": "csarron/bert-base-uncased-squad-v1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2021-12-07 23:45:02,729 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2021-12-07 23:45:03,690 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2021-12-07 23:45:03,690 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 12/07/2021 23:45:03 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 2293.13it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 104.99it/s]
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 252764.08it/s]
# 12/07/2021 23:45:05 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1.1_384_train_otquad
# 12/07/2021 23:45:05 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/07/2021 23:45:05 - INFO - __main__ -   Num examples = 128
# 12/07/2021 23:45:05 - INFO - __main__ -   Batch size = 96
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  6.08it/s]
# 12/07/2021 23:45:05 - INFO - __main__ -   Evaluation done in total 0.350383 secs (0.002737 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-07 23:45:05,895 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-07 23:45:05,895 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 12/07/2021 23:45:06 - INFO - __main__ - Results: {'exact': 63.28125, 'f1': 84.9699291739332, 'total': 128, 'HasAns_exact': 63.28125, 'HasAns_f1': 84.9699291739332, 'HasAns_total': 128, 'best_exact': 63.28125, 'best_exact_thresh': 0.0, 'best_f1': 84.9699291739332, 'best_f1_thresh': 0.0}

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path bert-base-uncased  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 12/08/2021 12:34:01 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2021-12-08 12:34:02,070 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2021-12-08 12:34:02,071 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|configuration_utils.py:530] 2021-12-08 12:34:02,323 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2021-12-08 12:34:02,325 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1717] 2021-12-08 12:34:02,946 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1717] 2021-12-08 12:34:02,947 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2021-12-08 12:34:02,947 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2021-12-08 12:34:02,947 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|tokenization_utils_base.py:1717] 2021-12-08 12:34:02,947 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|modeling_utils.py:1161] 2021-12-08 12:34:03,145 >> loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# [WARNING|modeling_utils.py:1337] 2021-12-08 12:34:04,747 >> Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2021-12-08 12:34:04,747 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 12/08/2021 12:34:07 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='bert-base-uncased', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='bert-base-uncased', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 12/08/2021 12:34:07 - INFO - __main__ - Loading checkpoint bert-base-uncased for evaluation
# 12/08/2021 12:34:07 - INFO - __main__ - Evaluate the following checkpoints: ['bert-base-uncased']
# [INFO|configuration_utils.py:530] 2021-12-08 12:34:07,681 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2021-12-08 12:34:07,682 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1161] 2021-12-08 12:34:07,810 >> loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/pretrained/huggingface/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# [WARNING|modeling_utils.py:1337] 2021-12-08 12:34:09,268 >> Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2021-12-08 12:34:09,268 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 12/08/2021 12:34:09 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 100%|███████████████████████████████████████| 128/128 [00:00<00:00, 3210.97it/s]
# convert squad examples to features: 100%|████| 128/128 [00:01<00:00, 102.71it/s]
# add example index and unique id: 100%|████| 128/128 [00:00<00:00, 243478.87it/s]
# 12/08/2021 12:34:10 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 12/08/2021 12:34:11 - INFO - __main__ - ***** Running evaluation otquad *****
# 12/08/2021 12:34:11 - INFO - __main__ -   Num examples = 128
# 12/08/2021 12:34:11 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:10<00:00,  5.10s/it]
# 12/08/2021 12:34:21 - INFO - __main__ -   Evaluation done in total 10.209528 secs (0.079762 sec per example)
# [INFO|squad_metrics.py:401] 2021-12-08 12:34:21,295 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2021-12-08 12:34:21,295 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 12/08/2021 12:34:21 - INFO - __main__ - Results: {'exact': 0.0, 'f1': 10.224855044060858, 'total': 128, 'HasAns_exact': 0.0, 'HasAns_f1': 10.224855044060858, 'HasAns_total': 128, 'best_exact': 0.0, 'best_exact_thresh': 0.0, 'best_f1': 10.224855044060858, 'best_f1_thresh': 0.0}

# %% [markdown]
# Results: {'exact': 0.0, 'f1': 10.224855044060858, 'total': 128, 'HasAns_exact': 0.0, 'HasAns_f1': 10.224855044060858, 'HasAns_total': 128, 'best_exact': 0.0, 'best_exact_thresh': 0.0, 'best_f1': 10.224855044060858, 'best_f1_thresh': 0.0} - RAW BERT MODEL

# %% [markdown]
# Results: {'exact': 6.25, 'f1': 18.921756858079615, 'total': 128, 'HasAns_exact': 6.25, 'HasAns_f1': 18.921756858079615, 'HasAns_total': 128, 'best_exact': 6.25, 'best_exact_thresh': 0.0, 'best_f1': 18.921756858079615, 'best_f1_thresh': 0.0}

# %% [markdown]
# Results: {'exact': 57.03125, 'f1': 82.77266925827892, 'total': 128, 'HasAns_exact': 57.03125, 'HasAns_f1': 82.77266925827892, 'HasAns_total': 128, 'best_exact': 57.03125, 'best_exact_thresh': 0.0, 'best_f1': 82.77266925827892, 'best_f1_thresh': 0.0} -- ONLY SQUAD

# %% [markdown]
# Results: {'exact': 67.96875, 'f1': 86.23642543452058, 'total': 128, 'HasAns_exact': 67.96875, 'HasAns_f1': 86.23642543452058, 'HasAns_total': 128, 'best_exact': 67.96875, 'best_exact_thresh': 0.0, 'best_f1': 86.23642543452058, 'best_f1_thresh': 0.0}

# %%
import matplotlib.pyplot as plt


def plot_perf(em, f1, best_epoch, best_em, best_f1, model_name):
    plt.figure(figsize=(9, 6))
    plt.plot(range(len(em)), em, 'o-', alpha=0.5, label='Exact Match (EM-Score)')
    plt.plot(range(len(f1)), f1, 'o-', alpha=0.5,
             label='Partial Match (F1-Score)')
    plt.plot([best_epoch]*len(em), range(0, 100), '--k', alpha=0.2,
             label=f'Best Score\n(EM={best_em:.2f}, F1={best_f1:.2f})')
    plt.xticks(size=13)
    plt.yticks(size=13)
    plt.ylim(0, 90)
    plt.xlabel('#Epoch', size=14)
    plt.ylabel('#Performance Score', size=14)
    plt.title(
        f"Performance of the '{model_name}' \ntransformer MRC model on test set",
        size=14
    )
    plt.legend(loc='lower right', fontsize=12)
    plt.show()

# %%
output_model_dir = '/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/'
model_name = 'BASE MODEL + OTQuAD'

with open(f'{output_model_dir}em.txt', 'r') as f:
    em = f.readlines()
with open(f'{output_model_dir}f1.txt', 'r') as f:
    f1 = f.readlines()
    
em = list(map(float, em[0][1:-2].split(',')))
f1 = list(map(float, f1[0][1:-2].split(',')))
best_epoch = f1.index(max(f1))
best_em = em[best_epoch]
best_f1 = f1[best_epoch]

plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)

# %%
output_model_dir = '/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/'
model_name = 'BASE MODEL + SQuAD + OTQuAD'

with open(f'{output_model_dir}em.txt', 'r') as f:
    em = f.readlines()
with open(f'{output_model_dir}f1.txt', 'r') as f:
    f1 = f.readlines()
    
em = list(map(float, em[0][1:-2].split(',')))
f1 = list(map(float, f1[0][1:-2].split(',')))
best_epoch = f1.index(max(f1))
best_em = em[best_epoch]
best_f1 = f1[best_epoch]

plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
