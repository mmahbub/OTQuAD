# %% [markdown]
# # tokenize test set

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path bert-base-uncased  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1550.40it/s]
# convert squad examples to features: 100%|████| 150/150 [00:01<00:00, 120.13it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 307200.00it/s]

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path bert-base-uncased-squad-v1  \
    --model_name_or_path csarron/bert-base-uncased-squad-v1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1526.04it/s]
# convert squad examples to features: 100%|████| 150/150 [00:01<00:00, 121.14it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 335723.37it/s]

# %% [markdown]
# # tokenize train set

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path bert-base-uncased  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --dataset_name otquad  \
    --do_train \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased_384_train_otquad
# 100%|███████████████████████████████████████| 650/650 [00:00<00:00, 1743.45it/s]
# convert squad examples to features:  49%|██▍  | 321/650 [00:02<00:05, 58.12it/s]Could not find answer: 'Follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics.' vs. 'follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics'
# convert squad examples to features: 100%|████| 650/650 [00:05<00:00, 109.24it/s]
# add example index and unique id: 100%|████| 650/650 [00:00<00:00, 366832.29it/s]

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path bert-base-uncased-squad-v1  \
    --model_name_or_path csarron/bert-base-uncased-squad-v1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --dataset_name otquad  \
    --do_train \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased-squad-v1_384_train_otquad
# 100%|███████████████████████████████████████| 650/650 [00:00<00:00, 1812.93it/s]
# convert squad examples to features:  49%|██▍  | 321/650 [00:03<00:06, 51.53it/s]Could not find answer: 'Follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics.' vs. 'follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics'
# convert squad examples to features: 100%|█████| 650/650 [00:06<00:00, 93.80it/s]
# add example index and unique id: 100%|████| 650/650 [00:00<00:00, 384472.94it/s]

# %% [markdown]
# # train bert-base-uncased

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path bert-base-uncased  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_train \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_train_batch_size 12 \
    --num_train_epochs 100.0 \
    --learning_rate  5e-5  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir
# Out:
# 03/09/2022 00:14:24 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-09 00:14:24,530 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2022-03-09 00:14:24,532 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|configuration_utils.py:530] 2022-03-09 00:14:24,877 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2022-03-09 00:14:24,878 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 00:14:25,699 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 00:14:25,700 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 00:14:25,700 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 00:14:25,700 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 00:14:25,700 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|modeling_utils.py:1161] 2022-03-09 00:14:26,062 >> loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# [WARNING|modeling_utils.py:1337] 2022-03-09 00:14:27,423 >> Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2022-03-09 00:14:27,423 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 03/09/2022 00:14:29 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=False, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=5e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='bert-base-uncased', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=100.0, orig_model_name_or_path='bert-base-uncased', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/', overwrite_cache=False, overwrite_output_dir=True, overwrite_output_model_dir=True, per_gpu_eval_batch_size=24, per_gpu_train_batch_size=12, predict_file=None, save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file='train_otquad.json', verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/09/2022 00:14:29 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased_384_train_otquad
# 03/09/2022 00:14:30 - INFO - __main__ - ***** Running training *****
# 03/09/2022 00:14:30 - INFO - __main__ -   Num examples = 879
# 03/09/2022 00:14:30 - INFO - __main__ -   Num Epochs = 100
# 03/09/2022 00:14:30 - INFO - __main__ -   Instantaneous batch size per GPU = 12
# 03/09/2022 00:14:30 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 48
# 03/09/2022 00:14:30 - INFO - __main__ -   Gradient Accumulation steps = 1
# 03/09/2022 00:14:30 - INFO - __main__ -   Total optimization steps = 1900
# Epoch:   0%|                                            | 0/100 [00:00<?, ?it/s]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]/net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:65: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
ached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:15:01 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:15:01 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:15:01 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.67it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.49it/s]
# 03/09/2022 00:15:01 - INFO - __main__ -   Evaluation done in total 0.364714 secs (0.002368 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:15:01,544 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:15:01,544 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   3%|█                                   | 3/100 [00:31<19:22, 11.98s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.89it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.88it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.87it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.86it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.86it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.86it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.63it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:04,  2.68it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:03<00:03,  2.72it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:03,  2.76it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  2.78it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.80it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:02,  2.81it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:05<00:01,  2.82it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:05<00:01,  2.83it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:01,  2.84it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:06<00:00,  2.85it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:06<00:00,  2.85it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  2.87it/s]
# 03/09/2022 00:15:08 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:15:08 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:15:08 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:15:08 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.70it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.50it/s]
# 03/09/2022 00:15:09 - INFO - __main__ -   Evaluation done in total 0.364388 secs (0.002366 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:15:09,303 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 
ached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:15:32 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:15:32 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:15:32 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.66it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.44it/s]
# 03/09/2022 00:15:32 - INFO - __main__ -   Evaluation done in total 0.368312 secs (0.002392 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:15:32,788 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:15:32,788 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   7%|██▌                                 | 7/100 [01:03<13:41,  8.84s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.85it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.84it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.84it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.84it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.83it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.84it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.85it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:03,  2.84it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:03<00:03,  2.84it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:03,  2.84it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  2.85it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.85it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:02,  2.67it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:05<00:01,  2.73it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:05<00:01,  2.76it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:01,  2.78it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:06<00:00,  2.79it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:06<00:00,  2.80it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  2.86it/s]
# 03/09/2022 00:15:40 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:15:40 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:15:40 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:15:40 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.59it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.39it/s]
# 03/09/2022 00:15:40 - INFO - __main__ -   Evaluation done in total 0.371349 secs (0.002411 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:15:40,668 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:15:40,668 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   8%|██▉                                 | 8/100 [01:11<13:06,  8.54s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.92it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.89it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.87it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.86it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.85it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.84it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.83it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:03,  2.83it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:03<00:03,  2.84it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:03,  2.85it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  2.84it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.84it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:02,  2.84it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:04<00:01,  2.83it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:05<00:01,  2.87it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:01,  2.73it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:06<00:00,  2.76it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:06<00:00,  2.78it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  2.88it/s]
# 03/09/2022 00:15:47 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:15:48 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:15:48 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:15:48 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.66it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.45it/s]
# 03/09/2022 00:15:48 - INFO - __main__ -   Evaluation done in total 0.367365 secs (0.002385 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:15:48,490 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:15:48,490 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   9%|███▏                                | 9/100 [01:18<12:37,  8.33s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.90it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.89it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.88it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.85it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.84it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.84it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.85it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:03,  2.85it/s]
ached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:16:03 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:16:03 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:16:03 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.67it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.48it/s]
# 03/09/2022 00:16:04 - INFO - __main__ -   Evaluation done in total 0.365685 secs (0.002375 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:16:04,119 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:16:04,120 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  11%|███▊                               | 11/100 [01:34<11:56,  8.05s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.96it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  3.00it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:00<00:05,  3.03it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:04,  3.06it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  3.07it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.93it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.96it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:03,  2.97it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:02<00:03,  3.00it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:02,  3.02it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  3.03it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:03<00:02,  3.06it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:01,  3.08it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:04<00:01,  3.09it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:04<00:01,  3.10it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:00,  3.10it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:05<00:00,  3.10it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:05<00:00,  3.07it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  3.11it/s]
# 03/09/2022 00:16:10 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:16:11 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:16:11 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:16:11 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.66it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.49it/s]
# 03/09/2022 00:16:11 - INFO - __main__ -   Evaluation done in total 0.364523 secs (0.002367 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:16:11,407 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:16:11,407 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epo
ached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:16:32 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:16:32 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:16:32 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.66it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.47it/s]
# 03/09/2022 00:16:33 - INFO - __main__ -   Evaluation done in total 0.365912 secs (0.002376 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:16:33,308 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# ...
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.86it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:02,  2.65it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:04<00:01,  2.71it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:05<00:01,  2.75it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:01,  2.78it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:06<00:00,  2.80it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:06<00:00,  2.82it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  2.87it/s]
# 03/09/2022 00:26:37 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:26:37 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:26:37 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:26:37 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.60it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.41it/s]
# 03/09/2022 00:26:37 - INFO - __main__ -   Evaluation done in total 0.370191 secs (0.002404 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:26:37,995 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:26:37,995 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  96%|█████████████████████████████████▌ | 96/100 [12:08<00:30,  7.72s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.91it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.89it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.87it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.86it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.85it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.85it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.84it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:03,  2.84it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:03<00:03,  2.77it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:03,  2.76it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  2.75it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.79it/s]
ached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:26:53 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:26:53 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:26:53 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.63it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.42it/s]
# 03/09/2022 00:26:53 - INFO - __main__ -   Evaluation done in total 0.369773 secs (0.002401 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:26:53,927 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:26:53,927 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  98%|██████████████████████████████████▎| 98/100 [12:24<00:15,  7.86s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.90it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.88it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.87it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.86it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.85it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.85it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.64it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:04,  2.70it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:03<00:03,  2.74it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:03,  2.77it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  2.79it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.81it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:02,  2.82it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:05<00:01,  2.82it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:05<00:01,  2.83it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:01,  2.83it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:06<00:00,  2.83it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:06<00:00,  2.83it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  2.86it/s]
# 03/09/2022 00:27:01 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:27:01 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:27:01 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:27:01 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.63it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.43it/s]
# 03/09/2022 00:27:01 - INFO - __main__ -   Evaluation done in total 0.368923 secs (0.002396 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:27:01,784 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:27:01,784 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  99%|██████████████████████████████████▋| 99/100 [12:32<00:07,  7.85s/it]
# Iteration:   0%|                                         | 0/19 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/19 [00:00<00:06,  2.88it/s]
# Iteration:  11%|███▍                             | 2/19 [00:00<00:05,  2.87it/s]
# Iteration:  16%|█████▏                           | 3/19 [00:01<00:05,  2.86it/s]
# Iteration:  21%|██████▉                          | 4/19 [00:01<00:05,  2.84it/s]
# Iteration:  26%|████████▋                        | 5/19 [00:01<00:04,  2.83it/s]
# Iteration:  32%|██████████▍                      | 6/19 [00:02<00:04,  2.63it/s]
# Iteration:  37%|████████████▏                    | 7/19 [00:02<00:04,  2.69it/s]
# Iteration:  42%|█████████████▉                   | 8/19 [00:02<00:04,  2.73it/s]
# Iteration:  47%|███████████████▋                 | 9/19 [00:03<00:03,  2.76it/s]
# Iteration:  53%|████████████████▊               | 10/19 [00:03<00:03,  2.78it/s]
# Iteration:  58%|██████████████████▌             | 11/19 [00:03<00:02,  2.79it/s]
# Iteration:  63%|████████████████████▏           | 12/19 [00:04<00:02,  2.79it/s]
# Iteration:  68%|█████████████████████▉          | 13/19 [00:04<00:02,  2.81it/s]
# Iteration:  74%|███████████████████████▌        | 14/19 [00:05<00:01,  2.82it/s]
# Iteration:  79%|█████████████████████████▎      | 15/19 [00:05<00:01,  2.83it/s]
# Iteration:  84%|██████████████████████████▉     | 16/19 [00:05<00:01,  2.84it/s]
# Iteration:  89%|████████████████████████████▋   | 17/19 [00:06<00:00,  2.85it/s]
# Iteration:  95%|██████████████████████████████▎ | 18/19 [00:06<00:00,  2.85it/s]
# Iteration: 100%|████████████████████████████████| 19/19 [00:06<00:00,  2.85it/s]
# 03/09/2022 00:27:09 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:27:09 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:27:09 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:27:09 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.63it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.46it/s]
# 03/09/2022 00:27:09 - INFO - __main__ -   Evaluation done in total 0.366995 secs (0.002383 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:27:09,622 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:27:09,623 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch: 100%|██████████████████████████████████| 100/100 [12:39<00:00,  7.60s/it]
# 03/09/2022 00:27:10 - INFO - __main__ -  global_step = 1901, average loss = 0.21648522045829824
# 03/09/2022 00:27:10 - INFO - __main__ - Saving model checkpoint to /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/
# [INFO|configuration_utils.py:364] 2022-03-09 00:27:12,205 >> Configuration saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/config.json
# [INFO|modeling_utils.py:898] 2022-03-09 00:27:14,003 >> Model weights saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/pytorch_model.bin
# [INFO|tokenization_utils_base.py:1948] 2022-03-09 00:27:14,010 >> tokenizer config file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1954] 2022-03-09 00:27:14,017 >> Special tokens file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/special_tokens_map.json
# [INFO|configuration_utils.py:528] 2022-03-09 00:27:14,052 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-09 00:27:14,053 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-09 00:27:14,053 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-09 00:27:15,024 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-09 00:27:15,024 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# [INFO|tokenization_utils_base.py:1651] 2022-03-09 00:27:15,026 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-03-09 00:27:15,026 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:15,027 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:15,027 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:15,027 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:15,027 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:15,027 >> loading file None
# 03/09/2022 00:27:15 - INFO - __main__ - Results: {}

# %% [markdown]
# # test trained bert-base-uncased

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/09/2022 00:27:24 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:528] 2022-03-09 00:27:24,588 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-09 00:27:24,589 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1651] 2022-03-09 00:27:24,590 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-03-09 00:27:24,590 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:24,590 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:24,590 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:24,590 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:24,590 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-09 00:27:24,590 >> loading file None
# [INFO|modeling_utils.py:1159] 2022-03-09 00:27:24,788 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-09 00:27:25,768 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-09 00:27:25,768 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/09/2022 00:27:28 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='bert-base-uncased', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/09/2022 00:27:28 - INFO - __main__ - Loading checkpoint /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/ for evaluation
# 03/09/2022 00:27:28 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/']
# [INFO|configuration_utils.py:528] 2022-03-09 00:27:28,167 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-09 00:27:28,168 >> Model config BertConfig {
#   "_name_or_path": "bert-base-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-09 00:27:28,168 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-09 00:27:29,120 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-09 00:27:29,120 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/09/2022 00:27:29 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 00:27:29 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 00:27:29 - INFO - __main__ -   Num examples = 154
# 03/09/2022 00:27:29 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:08<00:00,  4.46s/it]
# 03/09/2022 00:27:38 - INFO - __main__ -   Evaluation done in total 8.912812 secs (0.057875 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 00:27:38,254 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 00:27:38,254 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/09/2022 00:27:38 - INFO - __main__ - Results: {'exact': 48.666666666666664, 'f1': 62.22221553557425, 'total': 150, 'HasAns_exact': 48.666666666666664, 'HasAns_f1': 62.22221553557425, 'HasAns_total': 150, 'best_exact': 48.666666666666664, 'best_exact_thresh': 0.0, 'best_f1': 62.22221553557425, 'best_f1_thresh': 0.0}

# %% [markdown]
# # test bert-base-uncased

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased  \
    --model_name_or_path bert-base-uncased  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/09/2022 09:46:54 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-09 09:46:54,804 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2022-03-09 09:46:54,806 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|configuration_utils.py:530] 2022-03-09 09:46:55,142 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2022-03-09 09:46:55,144 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 09:46:55,988 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/45c3f7a79a80e1cf0a489e5c62b43f173c15db47864303a55d623bb3c96f72a5.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 09:46:55,989 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 09:46:55,989 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 09:46:55,989 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer_config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/c1d7f0a763fb63861cc08553866f1fc3e5a6f4f07621be277452d26d71303b7e.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 09:46:55,989 >> loading file https://huggingface.co/bert-base-uncased/resolve/main/tokenizer.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/534479488c54aeaf9c3406f647aa2ec13648c06771ffe269edabebd4c412da1d.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# [INFO|modeling_utils.py:1161] 2022-03-09 09:46:56,328 >> loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# [WARNING|modeling_utils.py:1337] 2022-03-09 09:46:57,700 >> Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2022-03-09 09:46:57,700 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 03/09/2022 09:47:00 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='bert-base-uncased', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='bert-base-uncased', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/09/2022 09:47:00 - INFO - __main__ - Loading checkpoint bert-base-uncased for evaluation
# 03/09/2022 09:47:00 - INFO - __main__ - Evaluate the following checkpoints: ['bert-base-uncased']
# [INFO|configuration_utils.py:530] 2022-03-09 09:47:00,242 >> loading configuration file https://huggingface.co/bert-base-uncased/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/3c61d016573b14f7f008c02c4e51a366c67ab274726fe2910691e2a761acf43e.37395cee442ab11005bcd270f3c34464dc1704b715b5d7d52b1a461abe3b9e4e
# [INFO|configuration_utils.py:566] 2022-03-09 09:47:00,243 >> Model config BertConfig {
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1161] 2022-03-09 09:47:00,409 >> loading weights file https://huggingface.co/bert-base-uncased/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/a8041bf617d7f94ea26d15e218abd04afc2004805632abc0ed2066aa16d50d04.faf6ea826ae9c5867d12b22257f9877e6b8367890837bd60f7c54a29633f7f2f
# [WARNING|modeling_utils.py:1337] 2022-03-09 09:47:01,757 >> Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2022-03-09 09:47:01,758 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 03/09/2022 09:47:01 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased_384_test_otquad
# 03/09/2022 09:47:01 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 09:47:01 - INFO - __main__ -   Num examples = 154
# 03/09/2022 09:47:01 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:09<00:00,  4.67s/it]
# 03/09/2022 09:47:11 - INFO - __main__ -   Evaluation done in total 9.348077 secs (0.060702 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 09:47:11,268 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 09:47:11,268 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/09/2022 09:47:11 - INFO - __main__ - Results: {'exact': 0.0, 'f1': 5.195077712459661, 'total': 150, 'HasAns_exact': 0.0, 'HasAns_f1': 5.195077712459661, 'HasAns_total': 150, 'best_exact': 0.0, 'best_exact_thresh': 0.0, 'best_f1': 5.195077712459661, 'best_f1_thresh': 0.0}

# %% [markdown]
# # train bert-base-uncased-squad-v1

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased-squad-v1  \
    --model_name_or_path csarron/bert-base-uncased-squad-v1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_train \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_train_batch_size 12 \
    --num_train_epochs 1.0 \
    --learning_rate  5e-5  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir \
    --overwrite_cache
# Out:
# 04/06/2022 03:21:18 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-04-06 03:21:18,844 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2022-04-06 03:21:18,845 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|configuration_utils.py:530] 2022-04-06 03:21:19,175 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2022-04-06 03:21:19,176 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-04-06 03:21:20,025 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/d1151882521c5317bfebfc93bbab1266ec34c0f92ca2b03d9d2661905be15ab1.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1717] 2022-04-06 03:21:20,025 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-04-06 03:21:20,026 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/special_tokens_map.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/c1d618b70fc6898914e51fe9281c26e67b5c171dec2bf45f76e01124df96cbb6.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# [INFO|tokenization_utils_base.py:1717] 2022-04-06 03:21:20,026 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/tokenizer_config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/aa051bd945f38953e3bb49399e953855a5dde0fc46dd93899607162698cbdb63.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# [INFO|tokenization_utils_base.py:1717] 2022-04-06 03:21:20,026 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/tokenizer.json from cache at None
# [INFO|modeling_utils.py:1161] 2022-04-06 03:21:20,311 >> loading weights file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/cc49866c357ded9e5e5047656847944e31b4fdbac69bd2ddd8567352acac8973.9113a3a907fc5caecafe526ef30b1b18dd4dcc741d60cb2080ae038c9b3b0cba
# [INFO|modeling_utils.py:1345] 2022-04-06 03:21:21,585 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-04-06 03:21:21,585 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at csarron/bert-base-uncased-squad-v1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 04/06/2022 03:21:24 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=5e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='csarron/bert-base-uncased-squad-v1', model_type='bert', n_best_size=20, n_gpu=1, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=1.0, orig_model_name_or_path='bert-base-uncased-squad-v1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/', overwrite_cache=True, overwrite_output_dir=True, overwrite_output_model_dir=True, per_gpu_eval_batch_size=24, per_gpu_train_batch_size=12, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file='train_otquad.json', verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 04/06/2022 03:21:24 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased-squad-v1_384_train_otquad
# 100%|███████████████████████████████████████| 650/650 [00:00<00:00, 2283.69it/s]
# convert squad examples to features:  49%|██▍  | 321/650 [00:03<00:07, 43.29it/s][WARNING|squad.py:118] 2022-04-06 03:21:29,631 >> Could not find answer: 'Follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics.' vs. 'follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics'
# convert squad examples to features: 100%|█████| 650/650 [00:08<00:00, 73.61it/s]
# add example index and unique id: 100%|████| 650/650 [00:00<00:00, 301414.88it/s]
# 04/06/2022 03:21:33 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bert-base-uncased-squad-v1_384_train_otquad
# 04/06/2022 03:21:34 - INFO - __main__ - ***** Running training *****
# 04/06/2022 03:21:34 - INFO - __main__ -   Num examples = 881
# 04/06/2022 03:21:34 - INFO - __main__ -   Num Epochs = 1
# 04/06/2022 03:21:34 - INFO - __main__ -   Instantaneous batch size per GPU = 12
# 04/06/2022 03:21:34 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 12
# 04/06/2022 03:21:34 - INFO - __main__ -   Gradient Accumulation steps = 1
# 04/06/2022 03:21:34 - INFO - __main__ -   Total optimization steps = 74
# Epoch:   0%|                                              | 0/1 [00:00<?, ?it/s]
# Iteration:   0%|                                         | 0/74 [00:00<?, ?it/s]
# Iteration:   1%|▍                                | 1/74 [00:00<01:05,  1.11it/s]
# Iteration:   3%|▉                                | 2/74 [00:01<00:51,  1.39it/s]
# Iteration:   4%|█▎                               | 3/74 [00:01<00:41,  1.71it/s]
# Iteration:   5%|█▊                               | 4/74 [00:01<00:34,  2.01it/s]
# Iteration:   7%|██▏                              | 5/74 [00:02<00:30,  2.29it/s]
# Iteration:   8%|██▋                              | 6/74 [00:02<00:26,  2.54it/s]
# Iteration:   9%|███                              | 7/74 [00:02<00:24,  2.74it/s]
# Iteration:  11%|███▌                             | 8/74 [00:02<00:22,  2.88it/s]
# Iteration:  12%|████                             | 9/74 [00:03<00:21,  3.01it/s]
# Iteration:  14%|████▎                           | 10/74 [00:03<00:20,  3.12it/s]
# Iteration:  15%|████▊                           | 11/74 [00:03<00:19,  3.20it/s]
# Iteration:  16%|█████▏                          | 12/74 [00:04<00:19,  3.25it/s]
# Iteration:  18%|█████▌                          | 13/74 [00:04<00:18,  3.29it/s]
# Iteration:  19%|██████                          | 14/74 [00:04<00:18,  3.31it/s]
# Iteration:  20%|██████▍                         | 15/74 [00:05<00:17,  3.32it/s]
# Iteration:  22%|██████▉                         | 16/74 [00:05<00:17,  3.34it/s]
# Iteration:  23%|███████▎                        | 17/74 [00:05<00:16,  3.35it/s]
# Iteration:  24%|███████▊                        | 18/74 [00:05<00:16,  3.36it/s]
# Iteration:  76%|████████████████████████▏       | 56/74 [00:16<00:05,  3.39it/s]
# Iteration:  77%|████████████████████████▋       | 57/74 [00:17<00:05,  3.38it/s]
# Iteration:  78%|█████████████████████████       | 58/74 [00:17<00:04,  3.38it/s]
# Iteration:  80%|█████████████████████████▌      | 59/74 [00:17<00:04,  3.37it/s]
# Iteration:  81%|█████████████████████████▉      | 60/74 [00:18<00:04,  3.37it/s]
# Iteration:  82%|██████████████████████████▍     | 61/74 [00:18<00:03,  3.36it/s]
# Iteration:  84%|██████████████████████████▊     | 62/74 [00:18<00:03,  3.37it/s]
# Iteration:  85%|███████████████████████████▏    | 63/74 [00:19<00:03,  3.38it/s]
# Iteration:  86%|███████████████████████████▋    | 64/74 [00:19<00:02,  3.38it/s]
# Iteration:  88%|████████████████████████████    | 65/74 [00:19<00:02,  3.39it/s]
# Iteration:  89%|████████████████████████████▌   | 66/74 [00:19<00:02,  3.39it/s]
# Iteration:  91%|████████████████████████████▉   | 67/74 [00:20<00:02,  3.38it/s]
# Iteration:  92%|█████████████████████████████▍  | 68/74 [00:20<00:01,  3.38it/s]
# Iteration:  93%|█████████████████████████████▊  | 69/74 [00:20<00:01,  3.38it/s]
# Iteration:  95%|██████████████████████████████▎ | 70/74 [00:21<00:01,  3.38it/s]
# Iteration:  96%|██████████████████████████████▋ | 71/74 [00:21<00:00,  3.38it/s]
# Iteration:  97%|███████████████████████████████▏| 72/74 [00:21<00:00,  3.37it/s]
# Iteration:  99%|███████████████████████████████▌| 73/74 [00:22<00:00,  3.38it/s]
# Iteration: 100%|████████████████████████████████| 74/74 [00:22<00:00,  3.34it/s]
# 04/06/2022 03:21:57 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
#
#   0%|                                                   | 0/150 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1323.90it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:53,  2.81it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.95it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.52it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.66it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 80.66it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 409866.84it/s]
# 04/06/2022 03:21:59 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
# 04/06/2022 03:21:59 - INFO - __main__ - ***** Running evaluation otquad *****
# 04/06/2022 03:21:59 - INFO - __main__ -   Num examples = 154
# 04/06/2022 03:21:59 - INFO - __main__ -   Batch size = 24
#
# Evaluating:   0%|                                         | 0/7 [00:00<?, ?it/s]
# Evaluating:  14%|████▋                            | 1/7 [00:00<00:01,  5.69it/s]
# Evaluating:  29%|█████████▍                       | 2/7 [00:00<00:00,  5.72it/s]
# Evaluating:  43%|██████████████▏                  | 3/7 [00:00<00:00,  5.74it/s]
# Evaluating:  57%|██████████████████▊              | 4/7 [00:00<00:00,  5.76it/s]
# Evaluating:  71%|███████████████████████▌         | 5/7 [00:00<00:00,  5.76it/s]
# Evaluating: 100%|█████████████████████████████████| 7/7 [00:01<00:00,  6.28it/s]
# 04/06/2022 03:22:00 - INFO - __main__ -   Evaluation done in total 1.115445 secs (0.007243 sec per example)
# [INFO|squad_metrics.py:401] 2022-04-06 03:22:00,649 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-04-06 03:22:00,649 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch: 100%|██████████████████████████████████████| 1/1 [00:26<00:00, 26.48s/it]
# 04/06/2022 03:22:01 - INFO - __main__ -  global_step = 75, average loss = 1.2060093073050182
# 04/06/2022 03:22:01 - INFO - __main__ - Saving model checkpoint to /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/
# [INFO|configuration_utils.py:364] 2022-04-06 03:22:03,352 >> Configuration saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|modeling_utils.py:898] 2022-04-06 03:22:05,201 >> Model weights saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|tokenization_utils_base.py:1948] 2022-04-06 03:22:05,209 >> tokenizer config file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1954] 2022-04-06 03:22:05,212 >> Special tokens file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/special_tokens_map.json
# [INFO|configuration_utils.py:528] 2022-04-06 03:22:05,259 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-04-06 03:22:05,260 >> Model config BertConfig {
#   "_name_or_path": "csarron/bert-base-uncased-squad-v1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2022-04-06 03:22:05,261 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-04-06 03:22:06,546 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-04-06 03:22:06,547 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# [INFO|tokenization_utils_base.py:1651] 2022-04-06 03:22:06,553 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-04-06 03:22:06,553 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:22:06,553 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:22:06,553 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:22:06,553 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:22:06,553 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:22:06,553 >> loading file None
# 04/06/2022 03:22:06 - INFO - __main__ - Loading checkpoints saved during training for evaluation
# 04/06/2022 03:22:06 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/']
# [INFO|configuration_utils.py:528] 2022-04-06 03:22:06,726 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-04-06 03:22:06,726 >> Model config BertConfig {
#   "_name_or_path": "csarron/bert-base-uncased-squad-v1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2022-04-06 03:22:06,726 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-04-06 03:22:07,719 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-04-06 03:22:07,719 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 04/06/2022 03:22:07 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1671.65it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 79.44it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 219980.98it/s]
# 04/06/2022 03:22:09 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
# 04/06/2022 03:22:10 - INFO - __main__ - ***** Running evaluation otquad *****
# 04/06/2022 03:22:10 - INFO - __main__ -   Num examples = 154
# 04/06/2022 03:22:10 - INFO - __main__ -   Batch size = 24
# Evaluating: 100%|█████████████████████████████████| 7/7 [00:01<00:00,  6.26it/s]
# 04/06/2022 03:22:11 - INFO - __main__ -   Evaluation done in total 1.118201 secs (0.007261 sec per example)
# [INFO|squad_metrics.py:401] 2022-04-06 03:22:11,348 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-04-06 03:22:11,348 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 04/06/2022 03:22:12 - INFO - __main__ - Results: {'exact': 67.33333333333333, 'f1': 81.87939255473864, 'total': 150, 'HasAns_exact': 67.33333333333333, 'HasAns_f1': 81.87939255473864, 'HasAns_total': 150, 'best_exact': 67.33333333333333, 'best_exact_thresh': 0.0, 'best_f1': 81.87939255473864, 'best_f1_thresh': 0.0}

# %% [markdown]
# # test trained bert-base-uncased-squad-v1

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased-squad-v1  \
    --model_name_or_path /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 04/06/2022 03:13:19 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:528] 2022-04-06 03:13:19,614 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-04-06 03:13:19,614 >> Model config BertConfig {
#   "_name_or_path": "csarron/bert-base-uncased-squad-v1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1651] 2022-04-06 03:13:19,616 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-04-06 03:13:19,616 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:13:19,616 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:13:19,616 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:13:19,616 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:13:19,616 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-04-06 03:13:19,616 >> loading file None
# [INFO|modeling_utils.py:1159] 2022-04-06 03:13:19,711 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-04-06 03:13:20,966 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-04-06 03:13:20,966 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 04/06/2022 03:13:24 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/', model_type='bert', n_best_size=20, n_gpu=1, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='bert-base-uncased-squad-v1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 04/06/2022 03:13:24 - INFO - __main__ - Loading checkpoint /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/ for evaluation
# 04/06/2022 03:13:24 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/']
# [INFO|configuration_utils.py:528] 2022-04-06 03:13:24,189 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-04-06 03:13:24,189 >> Model config BertConfig {
#   "_name_or_path": "csarron/bert-base-uncased-squad-v1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1159] 2022-04-06 03:13:24,190 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-04-06 03:13:25,335 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-04-06 03:13:25,335 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 04/06/2022 03:13:25 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
# 04/06/2022 03:13:25 - INFO - __main__ - ***** Running evaluation otquad *****
# 04/06/2022 03:13:25 - INFO - __main__ -   Num examples = 154
# 04/06/2022 03:13:25 - INFO - __main__ -   Batch size = 20
# Evaluating: 100%|█████████████████████████████████| 8/8 [00:01<00:00,  5.63it/s]
# 04/06/2022 03:13:27 - INFO - __main__ -   Evaluation done in total 1.423378 secs (0.009243 sec per example)
# [INFO|squad_metrics.py:401] 2022-04-06 03:13:27,023 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-04-06 03:13:27,023 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 04/06/2022 03:13:27 - INFO - __main__ - Results: {'exact': 64.0, 'f1': 77.58927124092097, 'total': 150, 'HasAns_exact': 64.0, 'HasAns_f1': 77.58927124092097, 'HasAns_total': 150, 'best_exact': 64.0, 'best_exact_thresh': 0.0, 'best_f1': 77.58927124092097, 'best_f1_thresh': 0.0}

# %% [markdown]
# # test bert-base-uncased-squad-v1

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path bert-base-uncased-squad-v1  \
    --model_name_or_path csarron/bert-base-uncased-squad-v1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/09/2022 01:08:31 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-09 01:08:31,904 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2022-03-09 01:08:31,906 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|configuration_utils.py:530] 2022-03-09 01:08:32,239 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2022-03-09 01:08:32,241 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 01:08:33,059 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/d1151882521c5317bfebfc93bbab1266ec34c0f92ca2b03d9d2661905be15ab1.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 01:08:33,060 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 01:08:33,060 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/special_tokens_map.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/c1d618b70fc6898914e51fe9281c26e67b5c171dec2bf45f76e01124df96cbb6.dd8bd9bfd3664b530ea4e645105f557769387b3da9f79bdb55ed556bdd80611d
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 01:08:33,060 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/tokenizer_config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/aa051bd945f38953e3bb49399e953855a5dde0fc46dd93899607162698cbdb63.76ea01b4b85ac16e2cec55c398cba7a943d89ab21dfdd973f6630a152e4b9aed
# [INFO|tokenization_utils_base.py:1717] 2022-03-09 01:08:33,060 >> loading file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/tokenizer.json from cache at None
# [INFO|modeling_utils.py:1161] 2022-03-09 01:08:33,457 >> loading weights file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/cc49866c357ded9e5e5047656847944e31b4fdbac69bd2ddd8567352acac8973.9113a3a907fc5caecafe526ef30b1b18dd4dcc741d60cb2080ae038c9b3b0cba
# [INFO|modeling_utils.py:1345] 2022-03-09 01:08:34,482 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-09 01:08:34,482 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at csarron/bert-base-uncased-squad-v1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/09/2022 01:08:36 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='csarron/bert-base-uncased-squad-v1', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='bert-base-uncased-squad-v1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/09/2022 01:08:36 - INFO - __main__ - Loading checkpoint csarron/bert-base-uncased-squad-v1 for evaluation
# 03/09/2022 01:08:36 - INFO - __main__ - Evaluate the following checkpoints: ['csarron/bert-base-uncased-squad-v1']
# [INFO|configuration_utils.py:530] 2022-03-09 01:08:36,979 >> loading configuration file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/640b91f8033e2e306d54097441ba060de086cfa8e2b334fc6ca7a40de0f56ed2.1afc8e7ce4fe9efe54e1f9ac968f42b33a2baac9f294d23e1123658693b0ec80
# [INFO|configuration_utils.py:566] 2022-03-09 01:08:36,980 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30522
# }
#
# [INFO|modeling_utils.py:1161] 2022-03-09 01:08:37,151 >> loading weights file https://huggingface.co/csarron/bert-base-uncased-squad-v1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/cc49866c357ded9e5e5047656847944e31b4fdbac69bd2ddd8567352acac8973.9113a3a907fc5caecafe526ef30b1b18dd4dcc741d60cb2080ae038c9b3b0cba
# [INFO|modeling_utils.py:1345] 2022-03-09 01:08:38,196 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-09 01:08:38,196 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at csarron/bert-base-uncased-squad-v1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/09/2022 01:08:38 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_bert-base-uncased-squad-v1_384_test_otquad
# 03/09/2022 01:08:38 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/09/2022 01:08:38 - INFO - __main__ -   Num examples = 154
# 03/09/2022 01:08:38 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:08<00:00,  4.31s/it]
# 03/09/2022 01:08:47 - INFO - __main__ -   Evaluation done in total 8.629397 secs (0.056035 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-09 01:08:47,055 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-09 01:08:47,055 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/09/2022 01:08:47 - INFO - __main__ - Results: {'exact': 49.333333333333336, 'f1': 70.33893356299586, 'total': 150, 'HasAns_exact': 49.333333333333336, 'HasAns_f1': 70.33893356299586, 'HasAns_total': 150, 'best_exact': 49.333333333333336, 'best_exact_thresh': 0.0, 'best_f1': 70.33893356299586, 'best_f1_thresh': 0.0}

# %%
import matplotlib.pyplot as plt


def plot_perf(em, f1, best_epoch, best_em, best_f1, model_name):
    plt.figure(figsize=(9, 6))
    plt.plot(range(len(em)), em, 'o-', alpha=0.5, label='Exact Match (EM-Score)')
    plt.plot(range(len(f1)), f1, 'o-', alpha=0.5,
             label='Partial Match (F1-Score)')
    plt.plot([best_epoch]*len(em), range(0, 100), '--k', alpha=0.2,
             label=f'Best Score\n(EM={best_em:.2f}, F1={best_f1:.2f})')
    plt.xticks(size=13)
    plt.yticks(size=13)
    plt.ylim(0, 90)
    plt.xlabel('#Epoch', size=14)
    plt.ylabel('#Performance Score', size=14)
    plt.title(
        f"Performance of the '{model_name}' \ntransformer MRC model on test set",
        size=14
    )
    plt.legend(loc='lower right', fontsize=12)
    plt.show()

# %%
output_model_dir = '/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-otquad/'
model_name = 'BASE MODEL + OTQuAD'

with open(f'{output_model_dir}em.txt', 'r') as f:
    em = f.readlines()
with open(f'{output_model_dir}f1.txt', 'r') as f:
    f1 = f.readlines()
    
em = list(map(float, em[0][1:-2].split(',')))
f1 = list(map(float, f1[0][1:-2].split(',')))
best_epoch = em.index(max(em))
best_em = em[best_epoch]
best_f1 = f1[best_epoch]

plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
print(best_epoch, best_em, best_f1)
# Out:
# 78 50.0 63.061329610096124

# %%
output_model_dir = '/net/kdinxidk03/opt/NFS/75y/data/qa/output/bert-squad-otquad/'
model_name = 'BASE MODEL + SQuAD + OTQuAD'

with open(f'{output_model_dir}em.txt', 'r') as f:
    em = f.readlines()
with open(f'{output_model_dir}f1.txt', 'r') as f:
    f1 = f.readlines()
    
em = list(map(float, em[0][1:-2].split(',')))
f1 = list(map(float, f1[0][1:-2].split(',')))
best_epoch = em.index(max(em))
best_em = em[best_epoch]
best_f1 = f1[best_epoch]

plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
print(best_epoch, best_em, best_f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-a19506361cc7> in <module>
#      13 best_f1 = f1[best_epoch]
#      14
# ---> 15 plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
#      16 print(best_epoch, best_em, best_f1)
#
# <ipython-input-12-146185f73fd6> in plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
#       8              label='Partial Match (F1-Score)')
#       9     plt.plot([best_epoch]*len(em), range(0, 100), '--k', alpha=0.2,
# ---> 10              label=f'Best Score\n(EM={best_em:.2f}, F1={best_f1:.2f})')
#      11     plt.xticks(size=13)
#      12     plt.yticks(size=13)
#
# /net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# /net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (100,)
