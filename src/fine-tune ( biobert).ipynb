# %% [markdown]
# # Tokenize

# %% [markdown]
# ## tokenize test set

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path biobert  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# Downloading: 100%|██████████████████████████████| 313/313 [00:00<00:00, 178kB/s]
# Downloading: 100%|███████████████████████████| 213k/213k [00:00<00:00, 1.83MB/s]
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert_384_test_otquad
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1185.55it/s]
# convert squad examples to features: 100%|████| 150/150 [00:01<00:00, 117.75it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 343607.65it/s]

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path biobert-squad-v1  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1-squad  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# Downloading: 100%|██████████████████████████████| 477/477 [00:00<00:00, 266kB/s]
# Downloading: 100%|███████████████████████████| 213k/213k [00:00<00:00, 1.70MB/s]
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1467.54it/s]
# convert squad examples to features: 100%|████| 150/150 [00:01<00:00, 118.37it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 304081.97it/s]

# %% [markdown]
# ## tokenize train set

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path biobert  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --dataset_name otquad  \
    --do_train \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_biobert_384_train_otquad
# 100%|███████████████████████████████████████| 650/650 [00:00<00:00, 1908.83it/s]
# convert squad examples to features:  49%|██▍  | 321/650 [00:02<00:05, 58.69it/s]Could not find answer: 'Follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics.' vs. 'follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics'
# convert squad examples to features: 100%|████| 650/650 [00:06<00:00, 104.01it/s]
# add example index and unique id: 100%|████| 650/650 [00:00<00:00, 373618.97it/s]

# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path biobert-squad-v1  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1-squad  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --dataset_name otquad  \
    --do_train \
    --max_seq_length 384   \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_biobert-squad-v1_384_train_otquad
# 100%|███████████████████████████████████████| 650/650 [00:00<00:00, 1946.92it/s]
# convert squad examples to features:  49%|██▍  | 321/650 [00:02<00:05, 57.15it/s]Could not find answer: 'Follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics.' vs. 'follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics'
# convert squad examples to features: 100%|████| 650/650 [00:06<00:00, 103.23it/s]
# add example index and unique id: 100%|████| 650/650 [00:00<00:00, 372241.62it/s]

# %% [markdown]
# # Training

# %% [markdown]
# ## train biobert-base-cased

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path biobert  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_train \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_train_batch_size 12 \
    --num_train_epochs 100.0 \
    --learning_rate  5e-5  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir
# Out:
# 03/23/2022 09:15:53 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-23 09:15:53,643 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/78e6e8ece5b58501028ce314273009ad7707ef4c5ba44251914fd6bca8a05eff.e4a2e693122d98b8b56b7dc1f0d89b644226aacef228afb5030ee3621b2829d3
# [INFO|configuration_utils.py:566] 2022-03-23 09:15:53,644 >> Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_auto.py:427] 2022-03-23 09:15:53,814 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:530] 2022-03-23 09:15:53,980 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/78e6e8ece5b58501028ce314273009ad7707ef4c5ba44251914fd6bca8a05eff.e4a2e693122d98b8b56b7dc1f0d89b644226aacef228afb5030ee3621b2829d3
# [INFO|configuration_utils.py:566] 2022-03-23 09:15:53,982 >> Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:15:54,816 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/cda9c238619f77c4dbf65f23ab841b5239f0289800d673957c843b9dda52ad44.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:15:54,817 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:15:54,817 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:15:54,817 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/tokenizer_config.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:15:54,817 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/tokenizer.json from cache at None
# 03/23/2022 09:15:55 - INFO - filelock - Lock 140424677662288 acquired on /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23.lock
# [INFO|file_utils.py:1590] 2022-03-23 09:15:55,148 >> https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/tmpli3v0omf
# Downloading: 100%|███████████████████████████| 436M/436M [00:05<00:00, 83.0MB/s]
# [INFO|file_utils.py:1594] 2022-03-23 09:16:01,534 >> storing https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/pytorch_model.bin in cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23
# [INFO|file_utils.py:1602] 2022-03-23 09:16:01,538 >> creating metadata file for /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23
# 03/23/2022 09:16:01 - INFO - filelock - Lock 140424677662288 released on /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23.lock
# [INFO|modeling_utils.py:1161] 2022-03-23 09:16:01,542 >> loading weights file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23
# [WARNING|modeling_utils.py:1337] 2022-03-23 09:16:03,870 >> Some weights of the model checkpoint at dmis-lab/biobert-base-cased-v1.1 were not used when initializing BertForQuestionAnswering: ['cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2022-03-23 09:16:03,871 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1 and are newly initialized: ['qa_outputs.weight', 'qa_outputs.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 03/23/2022 09:16:14 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=5e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='dmis-lab/biobert-base-cased-v1.1', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=100.0, orig_model_name_or_path='biobert', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/', overwrite_cache=False, overwrite_output_dir=True, overwrite_output_model_dir=True, per_gpu_eval_batch_size=24, per_gpu_train_batch_size=12, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file='train_otquad.json', verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/23/2022 09:16:14 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_biobert_384_train_otquad
# 03/23/2022 09:16:14 - INFO - __main__ - ***** Running training *****
# 03/23/2022 09:16:14 - INFO - __main__ -   Num examples = 943
# 03/23/2022 09:16:14 - INFO - __main__ -   Num Epochs = 100
# 03/23/2022 09:16:14 - INFO - __main__ -   Instantaneous batch size per GPU = 12
# 03/23/2022 09:16:14 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 48
# 03/23/2022 09:16:14 - INFO - __main__ -   Gradient Accumulation steps = 1
# 03/23/2022 09:16:14 - INFO - __main__ -   Total optimization steps = 2000
# Epoch:   0%|                                            | 0/100 [00:00<?, ?it/s]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]/net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:65: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#
# Iteration:   5%|█▋                               | 1/20 [00:10<03:17, 10.39s/it]
# Iteration:  10%|███▎                             | 2/20 [00:10<02:12,  7.39s/it]
# Iteration:  15%|████▉                            | 3/20 [00:11<01:29,  5.27s/it]
# Iteration:  20%|██████▌                          | 4/20 [00:11<01:00,  3.78s/it]
# Iteration:  25%|████████▎                        | 5/20 [00:11<00:41,  2.74s/it]
# Iteration:  30%|█████████▉                       | 6/20 [00:12<00:28,  2.01s/it]
# Iteration:  35%|███████████▌                     | 7/20 [00:12<00:19,  1.50s/it]
ached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert_384_test_otquad
# 03/23/2022 09:29:41 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:29:41 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:29:41 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  3.51it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.52it/s]
# 03/23/2022 09:29:41 - INFO - __main__ -   Evaluation done in total 0.443145 secs (0.002787 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:29:41,832 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:29:41,832 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch: 100%|██████████████████████████████████| 100/100 [13:27<00:00,  8.08s/it]
# 03/23/2022 09:29:42 - INFO - __main__ -  global_step = 2001, average loss = 0.13450382012480736
# 03/23/2022 09:29:42 - INFO - __main__ - Saving model checkpoint to /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/
# [INFO|configuration_utils.py:364] 2022-03-23 09:29:44,270 >> Configuration saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/config.json
# [INFO|modeling_utils.py:898] 2022-03-23 09:29:45,860 >> Model weights saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/pytorch_model.bin
# [INFO|tokenization_utils_base.py:1948] 2022-03-23 09:29:45,868 >> tokenizer config file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1954] 2022-03-23 09:29:45,871 >> Special tokens file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/special_tokens_map.json
# [INFO|configuration_utils.py:528] 2022-03-23 09:29:45,907 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 09:29:45,907 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-23 09:29:45,908 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 09:29:46,859 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:29:46,860 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 09:29:46,861 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 09:29:46,861 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:29:46,862 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:29:46,862 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:29:46,862 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:29:46,862 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:29:46,862 >> loading file None
# 03/23/2022 09:29:46 - INFO - __main__ - Loading checkpoints saved during training for evaluation
# 03/23/2022 09:29:46 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/']
# [INFO|configuration_utils.py:528] 2022-03-23 09:29:46,995 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 09:29:46,995 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-23 09:29:46,995 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 09:29:47,831 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:29:47,831 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:29:47 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert_384_test_otquad
# 03/23/2022 09:29:48 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:29:48 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:29:48 - INFO - __main__ -   Batch size = 96
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.27it/s]
# 03/23/2022 09:29:48 - INFO - __main__ -   Evaluation done in total 0.380173 secs (0.002391 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:29:48,434 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:29:48,434 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/23/2022 09:29:49 - INFO - __main__ - Results: {'exact': 58.666666666666664, 'f1': 70.91672231752676, 'total': 150, 'HasAns_exact': 58.666666666666664, 'HasAns_f1': 70.91672231752676, 'HasAns_total': 150, 'best_exact': 58.666666666666664, 'best_exact_thresh': 0.0, 'best_f1': 70.91672231752676, 'best_f1_thresh': 0.0}

# %% [markdown]
# ## train biobert-base-cased-squad

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path biobert-squad-v1  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1-squad  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --train_file train_otquad.json  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_train \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_train_batch_size 12 \
    --num_train_epochs 100.0 \
    --learning_rate  5e-5  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir \
    --overwrite_cache
# Out:
# 03/23/2022 09:38:35 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-23 09:38:35,935 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/73d216ac93bfc3819e606c86231a270ff173c8cc9824be895c0d9997ec04a536.1c046ef9d5292a28ccb3ce74621e0c56da3bd3c2e6a0b2e23c57cfa0c1c8d657
# [INFO|configuration_utils.py:566] 2022-03-23 09:38:35,937 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_auto.py:427] 2022-03-23 09:38:36,100 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:530] 2022-03-23 09:38:36,260 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/73d216ac93bfc3819e606c86231a270ff173c8cc9824be895c0d9997ec04a536.1c046ef9d5292a28ccb3ce74621e0c56da3bd3c2e6a0b2e23c57cfa0c1c8d657
# [INFO|configuration_utils.py:566] 2022-03-23 09:38:36,261 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:38:37,057 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/b62487cbb0952111a4d3965cecf20012d855a1b4cec1faa3c0302c0f2e5c8eed.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:38:37,057 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:38:37,057 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:38:37,057 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/tokenizer_config.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:38:37,058 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/tokenizer.json from cache at None
# 03/23/2022 09:38:37 - INFO - filelock - Lock 140491663494288 acquired on /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606.lock
# [INFO|file_utils.py:1590] 2022-03-23 09:38:37,468 >> https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/tmpaq0csmbm
# Downloading: 100%|███████████████████████████| 433M/433M [00:10<00:00, 39.4MB/s]
# [INFO|file_utils.py:1594] 2022-03-23 09:38:49,195 >> storing https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/pytorch_model.bin in cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606
# [INFO|file_utils.py:1602] 2022-03-23 09:38:49,207 >> creating metadata file for /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606
# 03/23/2022 09:38:49 - INFO - filelock - Lock 140491663494288 released on /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606.lock
# [INFO|modeling_utils.py:1161] 2022-03-23 09:38:49,220 >> loading weights file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606
# [INFO|modeling_utils.py:1345] 2022-03-23 09:38:51,200 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:38:51,200 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:38:53 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=True, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=5e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='dmis-lab/biobert-base-cased-v1.1-squad', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=100.0, orig_model_name_or_path='biobert-squad-v1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/', overwrite_cache=True, overwrite_output_dir=True, overwrite_output_model_dir=True, per_gpu_eval_batch_size=24, per_gpu_train_batch_size=12, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file='train_otquad.json', verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/23/2022 09:38:53 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_biobert-squad-v1_384_train_otquad
# 100%|███████████████████████████████████████| 650/650 [00:00<00:00, 2499.97it/s]
# convert squad examples to features:  49%|██▍  | 321/650 [00:03<00:07, 46.34it/s][WARNING|squad.py:118] 2022-03-23 09:38:58,216 >> Could not find answer: 'Follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics.' vs. 'follow-up 1 week to 1 month after each change in dosage and after discontinuation considering patient and treatment characteristics'
# convert squad examples to features: 100%|█████| 650/650 [00:08<00:00, 78.05it/s]
# add example index and unique id: 100%|████| 650/650 [00:00<00:00, 361434.12it/s]
# 03/23/2022 09:39:02 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_biobert-squad-v1_384_train_otquad
# 03/23/2022 09:39:03 - INFO - __main__ - ***** Running training *****
# 03/23/2022 09:39:03 - INFO - __main__ -   Num examples = 913
# 03/23/2022 09:39:03 - INFO - __main__ -   Num Epochs = 100
# 03/23/2022 09:39:03 - INFO - __main__ -   Instantaneous batch size per GPU = 12
# 03/23/2022 09:39:03 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 48
# 03/23/2022 09:39:03 - INFO - __main__ -   Gradient Accumulation steps = 1
# 03/23/2022 09:39:03 - INFO - __main__ -   Total optimization steps = 2000
# Epoch:   0%|                                            | 0/100 [00:00<?, ?it/s]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]/net/kdinxidk03/opt/NFS/75y/anaconda3/envs/QA/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:65: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#
# Iteration:   5%|█▋                               | 1/20 [00:10<03:14, 10.25s/it]
# Iteration:  10%|███▎                             | 2/20 [00:10<02:11,  7.28s/it]
# Iteration:  15%|████▉                            | 3/20 [00:10<01:28,  5.19s/it]
# Iteration:  20%|██████▌                          | 4/20 [00:11<00:59,  3.73s/it]
# Iteration:  25%|████████▎                        | 5/20 [00:11<00:40,  2.70s/it]
# Iteration:  30%|█████████▉                       | 6/20 [00:11<00:27,  1.99s/it]
# Iteration:  35%|███████████▌                     | 7/20 [00:12<00:19,  1.49s/it]
# Iteration:  40%|█████████████▏                   | 8/20 [00:12<00:13,  1.14s/it]
# Iteration:  45%|██████████████▊                  | 9/20 [00:12<00:09,  1.12it/s]
# Iteration:  50%|████████████████                | 10/20 [00:13<00:07,  1.32it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:13<00:05,  1.60it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:13<00:04,  1.88it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:14<00:03,  2.14it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:14<00:02,  2.37it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:14<00:01,  2.56it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:15<00:01,  2.71it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:15<00:01,  2.84it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:15<00:00,  2.93it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:16<00:00,  1.24it/s]
# 03/23/2022 09:39:19 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 2536.53it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.84it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  4.00it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.60it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.77it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.86it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 371177.35it/s]
# 03/23/2022 09:39:21 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:39:21 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:39:21 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:39:21 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.39it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.23it/s]
# 03/23/2022 09:39:22 - INFO - __main__ -   Evaluation done in total 0.382904 secs (0.002408 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:39:22,141 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:39:22,141 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   1%|▎                                   | 1/100 [00:19<32:02, 19.42s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.89it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:07,  2.51it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:06,  2.60it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:06,  2.65it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.70it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:05,  2.75it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.78it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.80it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.82it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.82it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:04<00:03,  2.78it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.78it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.78it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:05<00:02,  2.78it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.80it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.81it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.82it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.82it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.86it/s]
# 03/23/2022 09:39:29 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1860.33it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.82it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.97it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.56it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.71it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.96it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 327339.02it/s]
# 03/23/2022 09:39:31 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:39:32 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:39:32 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:39:32 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.69it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.42it/s]
# 03/23/2022 09:39:32 - INFO - __main__ -   Evaluation done in total 0.369327 secs (0.002323 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:39:32,401 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:39:32,401 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   2%|▋                                   | 2/100 [00:29<27:16, 16.70s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.87it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.87it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.86it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.85it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.85it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.84it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.85it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.84it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.85it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.84it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.84it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.83it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.84it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:02,  2.83it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.83it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.81it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.81it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.82it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.94it/s]
# 03/23/2022 09:39:39 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1875.96it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:53,  2.79it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.93it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.51it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.64it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.56it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 360748.62it/s]
# 03/23/2022 09:39:41 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:39:42 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:39:42 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:39:42 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.64it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.37it/s]
# 03/23/2022 09:39:42 - INFO - __main__ -   Evaluation done in total 0.372574 secs (0.002343 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:39:42,539 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:39:42,540 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   3%|█                                   | 3/100 [00:39<23:51, 14.76s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.88it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.88it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.89it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.89it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.87it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.87it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.85it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.84it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.83it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.83it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.83it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.84it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.84it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:02,  2.84it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.85it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.85it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.67it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.77it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.96it/s]
# 03/23/2022 09:39:50 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 2456.53it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<01:00,  2.48it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:33,  3.49it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:17,  4.90it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:07,  6.81it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 79.69it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 356456.43it/s]
# 03/23/2022 09:39:52 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:39:52 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:39:52 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:39:52 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.67it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.39it/s]
# 03/23/2022 09:39:52 - INFO - __main__ -   Evaluation done in total 0.371298 secs (0.002335 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:39:52,761 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:39:52,761 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   4%|█▍                                  | 4/100 [00:50<21:21, 13.35s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  3.10it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:05,  3.12it/s]
# Iteration:  15%|████▉                            | 3/20 [00:00<00:05,  3.14it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  3.14it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:04,  3.15it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:01<00:04,  3.15it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  3.16it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:03,  3.16it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:02<00:03,  3.17it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  3.17it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:02,  3.17it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:03<00:02,  3.17it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  3.05it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:01,  3.06it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:04<00:01,  3.07it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  3.09it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:05<00:01,  2.88it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:05<00:00,  2.95it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  3.20it/s]
# 03/23/2022 09:39:59 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
#   0%|                                                   | 0/150 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1271.43it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:50,  2.93it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:28,  4.12it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:14,  5.76it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.98it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.90it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 352462.52it/s]
# 03/23/2022 09:40:01 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:40:01 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:40:01 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:40:01 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.66it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.35it/s]
# 03/23/2022 09:40:02 - INFO - __main__ -   Evaluation done in total 0.374331 secs (0.002354 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:40:02,316 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:40:02,316 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   5%|█▊                                  | 5/100 [00:59<19:19, 12.21s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.79it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.79it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:06,  2.80it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.79it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.79it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:05,  2.79it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.79it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.78it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.77it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.77it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.83it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.91it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.98it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:01,  3.03it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  3.07it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  3.10it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:05<00:00,  3.11it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  3.12it/s]
# Iteration:  95%|██████████████████████████████▍ | 19/20 [00:06<00:00,  3.05it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  3.02it/s]
# 03/23/2022 09:40:09 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
#   0%|                                                   | 0/150 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1436.32it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.85it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  4.01it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.61it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.78it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 81.17it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 315203.21it/s]
# 03/23/2022 09:40:11 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:40:11 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:40:11 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:40:11 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.49it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.01it/s]
# 03/23/2022 09:40:12 - INFO - __main__ -   Evaluation done in total 0.499445 secs (0.003141 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:40:12,461 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:40:12,461 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   6%|██▏                                 | 6/100 [01:09<18:10, 11.61s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.89it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.87it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.88it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.85it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.85it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.86it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.88it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.88it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.85it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.85it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.78it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.77it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.76it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:02,  2.76it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.77it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.49it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.58it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.65it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.86it/s]
# 03/23/2022 09:40:20 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1842.57it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:55,  2.71it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:30,  3.81it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.32it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:07,  7.37it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 77.07it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 361785.85it/s]
# 03/23/2022 09:40:22 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:40:22 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:40:22 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:40:22 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.60it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.35it/s]
# 03/23/2022 09:40:22 - INFO - __main__ -   Evaluation done in total 0.374350 secs (0.002354 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:40:22,963 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:40:22,963 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   7%|██▌                                 | 7/100 [01:20<17:26, 11.26s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.82it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.80it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.84it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.88it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.90it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.89it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.91it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.94it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.98it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.76it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.79it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.85it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.94it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:01,  3.00it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  3.03it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  3.06it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:05<00:00,  3.05it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  3.05it/s]
# Iteration:  95%|██████████████████████████████▍ | 19/20 [00:06<00:00,  2.95it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  3.03it/s]
# 03/23/2022 09:40:30 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
#   0%|                                                   | 0/150 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1490.96it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.82it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.98it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.57it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.72it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 85.33it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 380148.40it/s]
# 03/23/2022 09:40:32 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:40:32 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:40:32 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:40:32 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.12it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.98it/s]
# 03/23/2022 09:40:32 - INFO - __main__ -   Evaluation done in total 0.402450 secs (0.002531 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:40:32,871 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:40:32,871 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   8%|██▉                                 | 8/100 [01:30<16:38, 10.85s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.87it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.86it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.87it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.87it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.89it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.93it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.94it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.94it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.91it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.65it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.72it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.78it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.81it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:02,  2.81it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.81it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.81it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.81it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.81it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.95it/s]
# 03/23/2022 09:40:40 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1584.97it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:53,  2.80it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.95it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.53it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.67it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.19it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 425961.81it/s]
# 03/23/2022 09:40:42 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:40:42 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:40:42 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:40:42 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.49it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.22it/s]
# 03/23/2022 09:40:42 - INFO - __main__ -   Evaluation done in total 0.383740 secs (0.002413 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:40:42,887 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:40:42,887 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:   9%|███▏                                | 9/100 [01:40<16:05, 10.61s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.82it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.83it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:06,  2.81it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.81it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.80it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.81it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:05,  2.60it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.66it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.76it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.80it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.80it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.80it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.80it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:05<00:02,  2.80it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.80it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.81it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.81it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.81it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.89it/s]
# 03/23/2022 09:40:50 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1810.49it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.83it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.99it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.59it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.74it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 79.60it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 359511.77it/s]
# 03/23/2022 09:40:52 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:40:52 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:40:52 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:40:52 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  4.10it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.96it/s]
# 03/23/2022 09:40:53 - INFO - __main__ -   Evaluation done in total 0.403624 secs (0.002539 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:40:53,229 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:40:53,229 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  10%|███▌                               | 10/100 [01:50<15:47, 10.53s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:08,  2.37it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:07,  2.48it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:06,  2.58it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:06,  2.64it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.67it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:05,  2.70it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.72it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.74it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.77it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.79it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.81it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.82it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.83it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:05<00:02,  2.83it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.83it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.83it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.83it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.84it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.90it/s]
# 03/23/2022 09:41:00 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1831.39it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.83it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.98it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.57it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.73it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 83.53it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 348557.12it/s]
# 03/23/2022 09:41:02 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:41:03 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:41:03 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:41:03 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  3.30it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.32it/s]
# 03/23/2022 09:41:03 - INFO - __main__ -   Evaluation done in total 0.463289 secs (0.002914 sec per example)
# ...
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1423.14it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.82it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  3.97it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.56it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.71it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.71it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 351281.74it/s]
# 03/23/2022 09:55:48 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:55:48 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:55:48 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:55:48 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  3.21it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.26it/s]
# 03/23/2022 09:55:49 - INFO - __main__ -   Evaluation done in total 0.469983 secs (0.002956 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:55:49,280 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:55:49,280 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  98%|██████████████████████████████████▎| 98/100 [16:46<00:20, 10.32s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.88it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.86it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.85it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.85it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.84it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.84it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.85it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.84it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.84it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.84it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.83it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.82it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.83it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:02,  2.83it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.83it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.83it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:05<00:01,  2.84it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.84it/s]
# Iteration:  95%|██████████████████████████████▍ | 19/20 [00:06<00:00,  2.84it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.93it/s]
# 03/23/2022 09:55:56 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#
#   0%|                                                   | 0/150 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1430.55it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:51,  2.90it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:28,  4.08it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:14,  5.71it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.91it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.16it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 355248.79it/s]
# 03/23/2022 09:55:58 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:55:59 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:55:59 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:55:59 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  3.14it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.21it/s]
# 03/23/2022 09:55:59 - INFO - __main__ -   Evaluation done in total 0.475833 secs (0.002993 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:55:59,568 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:55:59,568 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch:  99%|██████████████████████████████████▋| 99/100 [16:56<00:10, 10.28s/it]
# Iteration:   0%|                                         | 0/20 [00:00<?, ?it/s]
# Iteration:   5%|█▋                               | 1/20 [00:00<00:06,  2.91it/s]
# Iteration:  10%|███▎                             | 2/20 [00:00<00:06,  2.89it/s]
# Iteration:  15%|████▉                            | 3/20 [00:01<00:05,  2.87it/s]
# Iteration:  20%|██████▌                          | 4/20 [00:01<00:05,  2.86it/s]
# Iteration:  25%|████████▎                        | 5/20 [00:01<00:05,  2.84it/s]
# Iteration:  30%|█████████▉                       | 6/20 [00:02<00:04,  2.83it/s]
# Iteration:  35%|███████████▌                     | 7/20 [00:02<00:04,  2.82it/s]
# Iteration:  40%|█████████████▏                   | 8/20 [00:02<00:04,  2.82it/s]
# Iteration:  45%|██████████████▊                  | 9/20 [00:03<00:03,  2.81it/s]
# Iteration:  50%|████████████████                | 10/20 [00:03<00:03,  2.81it/s]
# Iteration:  55%|█████████████████▌              | 11/20 [00:03<00:03,  2.81it/s]
# Iteration:  60%|███████████████████▏            | 12/20 [00:04<00:02,  2.82it/s]
# Iteration:  65%|████████████████████▊           | 13/20 [00:04<00:02,  2.83it/s]
# Iteration:  70%|██████████████████████▍         | 14/20 [00:04<00:02,  2.83it/s]
# Iteration:  75%|████████████████████████        | 15/20 [00:05<00:01,  2.83it/s]
# Iteration:  80%|█████████████████████████▌      | 16/20 [00:05<00:01,  2.84it/s]
# Iteration:  85%|███████████████████████████▏    | 17/20 [00:06<00:01,  2.84it/s]
# Iteration:  90%|████████████████████████████▊   | 18/20 [00:06<00:00,  2.84it/s]
# Iteration:  95%|██████████████████████████████▍ | 19/20 [00:06<00:00,  2.84it/s]
# Iteration: 100%|████████████████████████████████| 20/20 [00:06<00:00,  2.93it/s]
# 03/23/2022 09:56:07 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
#   0%|                                                   | 0/150 [00:00<?, ?it/s]
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 1437.49it/s]
#
# convert squad examples to features:   0%|               | 0/150 [00:00<?, ?it/s]
# convert squad examples to features:   1%|       | 1/150 [00:00<00:52,  2.85it/s]
# convert squad examples to features:  22%|█▎    | 33/150 [00:00<00:29,  4.01it/s]
# convert squad examples to features:  43%|██▌   | 65/150 [00:01<00:15,  5.61it/s]
# convert squad examples to features:  65%|███▉  | 97/150 [00:01<00:06,  7.78it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 84.96it/s]
#
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 367491.59it/s]
# 03/23/2022 09:56:09 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:56:09 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:56:09 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:56:09 - INFO - __main__ -   Batch size = 96
#
# Evaluating:   0%|                                         | 0/2 [00:00<?, ?it/s]
# Evaluating:  50%|████████████████▌                | 1/2 [00:00<00:00,  3.07it/s]
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  4.15it/s]
# 03/23/2022 09:56:09 - INFO - __main__ -   Evaluation done in total 0.481817 secs (0.003030 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:56:09,796 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:56:09,796 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# Epoch: 100%|██████████████████████████████████| 100/100 [17:07<00:00, 10.27s/it]
# 03/23/2022 09:56:10 - INFO - __main__ -  global_step = 2001, average loss = 0.04015767778520771
# 03/23/2022 09:56:10 - INFO - __main__ - Saving model checkpoint to /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/
# [INFO|configuration_utils.py:364] 2022-03-23 09:56:12,054 >> Configuration saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/config.json
# [INFO|modeling_utils.py:898] 2022-03-23 09:56:13,612 >> Model weights saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/pytorch_model.bin
# [INFO|tokenization_utils_base.py:1948] 2022-03-23 09:56:13,625 >> tokenizer config file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1954] 2022-03-23 09:56:13,627 >> Special tokens file saved in /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/special_tokens_map.json
# [INFO|configuration_utils.py:528] 2022-03-23 09:56:13,652 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 09:56:13,653 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-23 09:56:13,653 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 09:56:14,597 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:56:14,597 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 09:56:14,599 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 09:56:14,599 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:56:14,599 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:56:14,599 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:56:14,600 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:56:14,600 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:56:14,600 >> loading file None
# 03/23/2022 09:56:14 - INFO - __main__ - Loading checkpoints saved during training for evaluation
# 03/23/2022 09:56:14 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/']
# [INFO|configuration_utils.py:528] 2022-03-23 09:56:14,707 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 09:56:14,707 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-23 09:56:14,708 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 09:56:15,647 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:56:15,647 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:56:15 - INFO - __main__ - Creating features from dataset file at /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 100%|███████████████████████████████████████| 150/150 [00:00<00:00, 2296.69it/s]
# convert squad examples to features: 100%|█████| 150/150 [00:01<00:00, 92.17it/s]
# add example index and unique id: 100%|████| 150/150 [00:00<00:00, 205737.61it/s]
# 03/23/2022 09:56:17 - INFO - __main__ - Saving features into cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:56:17 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:56:17 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:56:17 - INFO - __main__ -   Batch size = 96
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:00<00:00,  5.26it/s]
# 03/23/2022 09:56:18 - INFO - __main__ -   Evaluation done in total 0.381101 secs (0.002397 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:56:18,231 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:56:18,231 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/23/2022 09:56:18 - INFO - __main__ - Results: {'exact': 66.0, 'f1': 78.1633725959159, 'total': 150, 'HasAns_exact': 66.0, 'HasAns_f1': 78.1633725959159, 'HasAns_total': 150, 'best_exact': 66.0, 'best_exact_thresh': 0.0, 'best_f1': 78.1633725959159, 'best_f1_thresh': 0.0}

# %% [markdown]
# # Testing

# %% [markdown]
# ## test biobert-base-cased

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path biobert  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/23/2022 09:58:25 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-23 09:58:25,534 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/78e6e8ece5b58501028ce314273009ad7707ef4c5ba44251914fd6bca8a05eff.e4a2e693122d98b8b56b7dc1f0d89b644226aacef228afb5030ee3621b2829d3
# [INFO|configuration_utils.py:566] 2022-03-23 09:58:25,536 >> Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_auto.py:427] 2022-03-23 09:58:25,705 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:530] 2022-03-23 09:58:25,889 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/78e6e8ece5b58501028ce314273009ad7707ef4c5ba44251914fd6bca8a05eff.e4a2e693122d98b8b56b7dc1f0d89b644226aacef228afb5030ee3621b2829d3
# [INFO|configuration_utils.py:566] 2022-03-23 09:58:25,891 >> Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:58:26,711 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/cda9c238619f77c4dbf65f23ab841b5239f0289800d673957c843b9dda52ad44.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:58:26,712 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:58:26,712 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:58:26,712 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/tokenizer_config.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:58:26,712 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/tokenizer.json from cache at None
# [INFO|modeling_utils.py:1161] 2022-03-23 09:58:27,036 >> loading weights file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23
# [WARNING|modeling_utils.py:1337] 2022-03-23 09:58:28,388 >> Some weights of the model checkpoint at dmis-lab/biobert-base-cased-v1.1 were not used when initializing BertForQuestionAnswering: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2022-03-23 09:58:28,388 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1 and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 03/23/2022 09:58:30 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='dmis-lab/biobert-base-cased-v1.1', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='biobert', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/23/2022 09:58:30 - INFO - __main__ - Loading checkpoint dmis-lab/biobert-base-cased-v1.1 for evaluation
# 03/23/2022 09:58:30 - INFO - __main__ - Evaluate the following checkpoints: ['dmis-lab/biobert-base-cased-v1.1']
# [INFO|configuration_utils.py:530] 2022-03-23 09:58:30,920 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/78e6e8ece5b58501028ce314273009ad7707ef4c5ba44251914fd6bca8a05eff.e4a2e693122d98b8b56b7dc1f0d89b644226aacef228afb5030ee3621b2829d3
# [INFO|configuration_utils.py:566] 2022-03-23 09:58:30,922 >> Model config BertConfig {
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1161] 2022-03-23 09:58:31,078 >> loading weights file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/f22d3e86464eb4aa2e5f76e0560e9d595617f55e014c78f176b834f9245a62f0.2cf22e1fb1f2db88b971c8da5593b1e94a0ee79d8c892a0f6d4f607d2b77fa23
# [WARNING|modeling_utils.py:1337] 2022-03-23 09:58:32,605 >> Some weights of the model checkpoint at dmis-lab/biobert-base-cased-v1.1 were not used when initializing BertForQuestionAnswering: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [WARNING|modeling_utils.py:1348] 2022-03-23 09:58:32,605 >> Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1 and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 03/23/2022 09:58:32 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert_384_test_otquad
# 03/23/2022 09:58:32 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:58:32 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:58:32 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:08<00:00,  4.48s/it]
# 03/23/2022 09:58:41 - INFO - __main__ -   Evaluation done in total 8.971038 secs (0.056422 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:58:41,801 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:58:41,801 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/23/2022 09:58:42 - INFO - __main__ - Results: {'exact': 0.0, 'f1': 13.815927844634798, 'total': 150, 'HasAns_exact': 0.0, 'HasAns_f1': 13.815927844634798, 'HasAns_total': 150, 'best_exact': 0.0, 'best_exact_thresh': 0.0, 'best_f1': 13.815927844634798, 'best_f1_thresh': 0.0}

# %% [markdown]
# ## test trained biobert-base-cased-otquad

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path biobert  \
    --model_name_or_path /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/23/2022 09:58:50 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:528] 2022-03-23 09:58:50,300 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 09:58:50,301 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 09:58:50,303 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 09:58:50,304 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:58:50,304 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:58:50,304 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:58:50,304 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:58:50,304 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 09:58:50,304 >> loading file None
# [INFO|modeling_utils.py:1159] 2022-03-23 09:58:50,493 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 09:58:51,562 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:58:51,562 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:58:53 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='biobert', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/23/2022 09:58:53 - INFO - __main__ - Loading checkpoint /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/ for evaluation
# 03/23/2022 09:58:53 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/']
# [INFO|configuration_utils.py:528] 2022-03-23 09:58:53,986 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 09:58:53,987 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-23 09:58:53,987 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 09:58:54,893 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:58:54,893 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:58:55 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert_384_test_otquad
# 03/23/2022 09:58:55 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:58:55 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:58:55 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:08<00:00,  4.39s/it]
# 03/23/2022 09:59:03 - INFO - __main__ -   Evaluation done in total 8.782419 secs (0.055235 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:59:03,910 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:59:03,910 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/23/2022 09:59:04 - INFO - __main__ - Results: {'exact': 58.666666666666664, 'f1': 70.91672231752676, 'total': 150, 'HasAns_exact': 58.666666666666664, 'HasAns_f1': 70.91672231752676, 'HasAns_total': 150, 'best_exact': 58.666666666666664, 'best_exact_thresh': 0.0, 'best_f1': 70.91672231752676, 'best_f1_thresh': 0.0}

# %% [markdown]
# ## test biobert-base-cased-squad

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path biobert-squad-v1  \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1-squad  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/23/2022 09:59:31 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-03-23 09:59:31,839 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/73d216ac93bfc3819e606c86231a270ff173c8cc9824be895c0d9997ec04a536.1c046ef9d5292a28ccb3ce74621e0c56da3bd3c2e6a0b2e23c57cfa0c1c8d657
# [INFO|configuration_utils.py:566] 2022-03-23 09:59:31,841 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_auto.py:427] 2022-03-23 09:59:32,024 >> Could not locate the tokenizer configuration file, will try to use the model config instead.
# [INFO|configuration_utils.py:530] 2022-03-23 09:59:32,188 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/73d216ac93bfc3819e606c86231a270ff173c8cc9824be895c0d9997ec04a536.1c046ef9d5292a28ccb3ce74621e0c56da3bd3c2e6a0b2e23c57cfa0c1c8d657
# [INFO|configuration_utils.py:566] 2022-03-23 09:59:32,190 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:59:33,038 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/vocab.txt from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/b62487cbb0952111a4d3965cecf20012d855a1b4cec1faa3c0302c0f2e5c8eed.437aa611e89f6fc6675a049d2b5545390adbc617e7d655286421c191d2be2791
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:59:33,039 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:59:33,039 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:59:33,039 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/tokenizer_config.json from cache at None
# [INFO|tokenization_utils_base.py:1717] 2022-03-23 09:59:33,039 >> loading file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/tokenizer.json from cache at None
# [INFO|modeling_utils.py:1161] 2022-03-23 09:59:33,359 >> loading weights file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606
# [INFO|modeling_utils.py:1345] 2022-03-23 09:59:34,515 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:59:34,515 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:59:36 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='dmis-lab/biobert-base-cased-v1.1-squad', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='biobert-squad-v1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/23/2022 09:59:36 - INFO - __main__ - Loading checkpoint dmis-lab/biobert-base-cased-v1.1-squad for evaluation
# 03/23/2022 09:59:36 - INFO - __main__ - Evaluate the following checkpoints: ['dmis-lab/biobert-base-cased-v1.1-squad']
# [INFO|configuration_utils.py:530] 2022-03-23 09:59:37,153 >> loading configuration file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/73d216ac93bfc3819e606c86231a270ff173c8cc9824be895c0d9997ec04a536.1c046ef9d5292a28ccb3ce74621e0c56da3bd3c2e6a0b2e23c57cfa0c1c8d657
# [INFO|configuration_utils.py:566] 2022-03-23 09:59:37,155 >> Model config BertConfig {
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1161] 2022-03-23 09:59:37,331 >> loading weights file https://huggingface.co/dmis-lab/biobert-base-cased-v1.1-squad/resolve/main/pytorch_model.bin from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/9b5722abc76f0527415eb25455609f1b4f87d9292d753e2235727b5dc477a358.1db6bb4927152d374f25e432cab81cd5fb9f85e0cfc3ade0a73213115c395606
# [INFO|modeling_utils.py:1345] 2022-03-23 09:59:38,356 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 09:59:38,356 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at dmis-lab/biobert-base-cased-v1.1-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 09:59:38 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 09:59:38 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 09:59:38 - INFO - __main__ -   Num examples = 159
# 03/23/2022 09:59:38 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:09<00:00,  4.87s/it]
# 03/23/2022 09:59:48 - INFO - __main__ -   Evaluation done in total 9.751308 secs (0.061329 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 09:59:48,337 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 09:59:48,337 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/23/2022 09:59:48 - INFO - __main__ - Results: {'exact': 42.666666666666664, 'f1': 68.84135396162199, 'total': 150, 'HasAns_exact': 42.666666666666664, 'HasAns_f1': 68.84135396162199, 'HasAns_total': 150, 'best_exact': 42.666666666666664, 'best_exact_thresh': 0.0, 'best_f1': 68.84135396162199, 'best_f1_thresh': 0.0}

# %% [markdown]
# ## test trained biobert-base-cased-squad-otquad

# %%
# !python3 finetune_model.py  \
    --model_type bert   \
    --orig_model_name_or_path biobert-squad-v1  \
    --model_name_or_path /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir None \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/  \
    --predict_file test_otquad.json \
    --dataset_name otquad  \
    --do_evaluate \
    --max_seq_length 384   \
    --doc_stride 128  \
    --do_lower_case \
    --per_gpu_eval_batch_size 20 \
# Out:
# 03/23/2022 10:00:32 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 4, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:528] 2022-03-23 10:00:32,948 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 10:00:32,949 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 10:00:32,951 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/added_tokens.json. We won't load it.
# [INFO|tokenization_utils_base.py:1651] 2022-03-23 10:00:32,951 >> Didn't find file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/tokenizer.json. We won't load it.
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 10:00:32,952 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/vocab.txt
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 10:00:32,952 >> loading file None
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 10:00:32,952 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/special_tokens_map.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 10:00:32,952 >> loading file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/tokenizer_config.json
# [INFO|tokenization_utils_base.py:1715] 2022-03-23 10:00:32,952 >> loading file None
# [INFO|modeling_utils.py:1159] 2022-03-23 10:00:33,105 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 10:00:34,100 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 10:00:34,100 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 10:00:36 - INFO - __main__ - Training/evaluation parameters Namespace(adam_epsilon=1e-08, cache_dir='', config_name='', data_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/otquad/', dataset_name='otquad', device=device(type='cuda'), do_eval=False, do_evaluate=True, do_lower_case=True, do_train=False, doc_stride=128, eval_all_checkpoints=False, evaluate_during_training=False, fp16=False, fp16_opt_level='O1', gradient_accumulation_steps=1, lang_id=0, learning_rate=3e-05, local_rank=-1, logging_steps=500000, max_answer_length=30, max_grad_norm=1.0, max_query_length=64, max_seq_length=384, max_steps=-1, model_name_or_path='/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/', model_type='bert', n_best_size=20, n_gpu=4, no_cuda=False, null_score_diff_threshold=0.0, num_train_epochs=3.0, orig_model_name_or_path='biobert-squad-v1', output_dir='/net/kdinxidk03/opt/NFS/75y/data/qa/output/', output_model_dir='None', overwrite_cache=False, overwrite_output_dir=False, overwrite_output_model_dir=False, per_gpu_eval_batch_size=20, per_gpu_train_batch_size=24, predict_file='test_otquad.json', save_steps=500000, seed=42, server_ip='', server_port='', threads=1, tokenizer_name='', train_file=None, verbose_logging=False, version_2_with_negative=False, warmup_steps=0, weight_decay=0.0)
# 03/23/2022 10:00:36 - INFO - __main__ - Loading checkpoint /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/ for evaluation
# 03/23/2022 10:00:36 - INFO - __main__ - Evaluate the following checkpoints: ['/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/']
# [INFO|configuration_utils.py:528] 2022-03-23 10:00:36,514 >> loading configuration file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/config.json
# [INFO|configuration_utils.py:566] 2022-03-23 10:00:36,515 >> Model config BertConfig {
#   "_name_or_path": "dmis-lab/biobert-base-cased-v1.1-squad",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.8.2",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
# [INFO|modeling_utils.py:1159] 2022-03-23 10:00:36,515 >> loading weights file /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/pytorch_model.bin
# [INFO|modeling_utils.py:1345] 2022-03-23 10:00:37,446 >> All model checkpoint weights were used when initializing BertForQuestionAnswering.
#
# [INFO|modeling_utils.py:1354] 2022-03-23 10:00:37,446 >> All the weights of BertForQuestionAnswering were initialized from the model checkpoint at /net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertForQuestionAnswering for predictions without further training.
# 03/23/2022 10:00:37 - INFO - __main__ - Loading features from cached file /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_dev_biobert-squad-v1_384_test_otquad
# 03/23/2022 10:00:37 - INFO - __main__ - ***** Running evaluation otquad *****
# 03/23/2022 10:00:37 - INFO - __main__ -   Num examples = 159
# 03/23/2022 10:00:37 - INFO - __main__ -   Batch size = 80
# Evaluating: 100%|█████████████████████████████████| 2/2 [00:08<00:00,  4.22s/it]
# 03/23/2022 10:00:46 - INFO - __main__ -   Evaluation done in total 8.432850 secs (0.053037 sec per example)
# [INFO|squad_metrics.py:401] 2022-03-23 10:00:46,120 >> Writing predictions to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/predictions_otquad.json
# [INFO|squad_metrics.py:403] 2022-03-23 10:00:46,120 >> Writing nbest to: /net/kdinxidk03/opt/NFS/75y/data/qa/output/nbest_predictions_otquad.json
# 03/23/2022 10:00:46 - INFO - __main__ - Results: {'exact': 66.0, 'f1': 78.1633725959159, 'total': 150, 'HasAns_exact': 66.0, 'HasAns_f1': 78.1633725959159, 'HasAns_total': 150, 'best_exact': 66.0, 'best_exact_thresh': 0.0, 'best_f1': 78.1633725959159, 'best_f1_thresh': 0.0}

# %% [markdown]
# # Plot EM, F1

# %%
import matplotlib.pyplot as plt


def plot_perf(em, f1, best_epoch, best_em, best_f1, model_name):
    plt.figure(figsize=(9, 6))
    plt.plot(range(len(em)), em, 'o-', alpha=0.5, label='Exact Match (EM-Score)')
    plt.plot(range(len(f1)), f1, 'o-', alpha=0.5,
             label='Partial Match (F1-Score)')
    plt.plot([best_epoch]*len(em), range(0, 100), '--k', alpha=0.2,
             label=f'Best Score\n(EM={best_em:.2f}, F1={best_f1:.2f})')
    plt.xticks(size=13)
    plt.yticks(size=13)
    plt.ylim(0, 90)
    plt.xlabel('#Epoch', size=14)
    plt.ylabel('#Performance Score', size=14)
    plt.title(
        f"Performance of the '{model_name}' \ntransformer MRC model on test set",
        size=14
    )
    plt.legend(loc='lower right', fontsize=12)
    plt.show()

# %%
output_model_dir = '/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-otquad/'
model_name = 'BASE MODEL + OTQuAD'

with open(f'{output_model_dir}em.txt', 'r') as f:
    em = f.readlines()
with open(f'{output_model_dir}f1.txt', 'r') as f:
    f1 = f.readlines()
    
em = list(map(float, em[0][1:-2].split(',')))
f1 = list(map(float, f1[0][1:-2].split(',')))
best_epoch = em.index(max(em))
best_em = em[best_epoch]
best_f1 = f1[best_epoch]

plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
print(best_epoch, best_em, best_f1)
# Out:
# 56 60.666666666666664 74.3042353677772

# %%
output_model_dir = '/net/kdinxidk03/opt/NFS/75y/data/qa/output/biobert-squad-otquad/'
model_name = 'BASE MODEL + SQuAD + OTQuAD'

with open(f'{output_model_dir}em.txt', 'r') as f:
    em = f.readlines()
with open(f'{output_model_dir}f1.txt', 'r') as f:
    f1 = f.readlines()
    
em = list(map(float, em[0][1:-2].split(',')))
f1 = list(map(float, f1[0][1:-2].split(',')))
best_epoch = em.index(max(em))
best_em = em[best_epoch]
best_f1 = f1[best_epoch]

plot_perf(em, f1, best_epoch, best_em, best_f1, model_name)
print(best_epoch, best_em, best_f1)
# Out:
# 1 70.0 82.36047672898259
