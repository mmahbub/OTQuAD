# %%
# SQuAD		QuAC		BioASQ-9b		emrQA (medication)

# %%
from pathlib import Path

# %%
path = '/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/'

# %%
# squad
squad_train = json.load(open(path+'squad/train_squad.json'))
squad_test  = json.load(open(path+'squad/test_squad.json'))

print(len(squad_train['data']), len(squad_test['data']))
print(squad_train['data'][20])
# Out:
# 442 48
# ...

# %%
# quac
quac_train = json.load(open(path+'quac/train_quac.json'))
quac_test  = json.load(open(path+'quac/test_quac.json'))

print(len(quac_train['data'][0]), len(quac_test['data'][0]))
print(len(quac_test['data'][0]['paragraphs']))
# Out:
# 2 2
# 5868

# %%
# quac_json={
#           "data": [
#             {
#               "paragraphs":quac_test['data'],
#                "title":''
#             }],
#            "version":0
#        }  

# out_path = Path('/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/quac/')
# with open(out_path/f'test_quac_new.json', "w") as writer:
#     writer.write(json.dumps(quac_json, indent=4) + "\n")

# %%
import os

os.system('python3 load_dataset.py  --orig_model_name_or_path biolinkbert  --model_name_or_path michiyasunaga/BioLinkBERT-base  --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_lower_case --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path pubmedbert  --model_name_or_path microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract-fulltext  --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_lower_case --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path bioelectra  --model_name_or_path kamalkraj/bioelectra-base-discriminator-pubmed-pmc-lt  --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path biobert  --model_name_or_path dmis-lab/biobert-base-cased-v1.1  --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path scibert  --model_name_or_path allenai/scibert_scivocab_uncased  --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_lower_case --do_evaluate --max_seq_length 384   --doc_stride 128       --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path clinicalbert  --model_name_or_path emilyalsentzer/Bio_ClinicalBERT --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path roberta  --model_name_or_path roberta-base --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path bluebert  --model_name_or_path bionlp/bluebert_pubmed_mimic_uncased_L-12_H-768_A-12 --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

os.system('python3 load_dataset.py  --orig_model_name_or_path bert  --model_name_or_path bert-base-uncased --output_dir /net/kdinxidk03/opt/NFS/75y/data/OTMRC_PAPER/  --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  --predict_file relation-test.json --dataset_name emrqa_rel  --do_lower_case --do_evaluate --max_seq_length 384   --doc_stride 128  --overwrite_cache')

# %%
# relation-train-sampled-0.03.json
# relation-test.json
# Out:
# [{'answer_start': 177, 'text': 'Denver Broncos'},
#  {'answer_start': 177, 'text': 'Denver Broncos'},
#  {'answer_start': 177, 'text': 'Denver Broncos'}]

# %%
len(quac_train['data'])
# Out:
# 83568

# %%
### emrqa-medication
emrqa_train = json.load(open(path+'emrqa/datasets/medication-train-sampled-0.2.json'))
emrqa_test  = json.load(open(path+'emrqa/datasets/medication-test.json'))
emrqa_dev  = json.load(open(path+'emrqa/datasets/medication-dev.json'))

print(len(emrqa_train['data']), len(emrqa_test['data']), len(emrqa_dev['data']))
# print(emrqa_train['data'][10])
# 296 85 42 -- med
# 182 53 26 -- rel
# Out:
# 182 53 26

# %%
# bioasq
bioasq_train = json.load(open(path+'bioasq/train_bioasq9b.json'))
bioasq_test  = json.load(open(path+'bioasq/test_bioasq9b.json'))
bioasq_test
# print(len(bioasq_train['data'][0]['paragraphs']),
#       len(bioasq_test['data'][0]['paragraphs'])
#      )
# print(bioasq_train['data'][0]['paragraphs'][0])
# Out:
# {'data': [{'paragraphs': [{'qas': [{'id': '601bde6e1cb411341a000006_000',
#        'question': 'Which disease is caused by de novo VPS4A mutations?',
#        'answers': [{'answer_start': 30,
#          'text': 'Multisystem disease with abnormal neurodevelopment'}]}],
#      'context': 'De Novo VPS4A Mutations Cause Multisystem Disease with Abnormal Neurodevelopment.'},
#     {'qas': [{'id': '5e6d1c6f1af46fc130000021_000',
#        'question': 'Han Wistar and Sprague Dawley are breeds of what laboratory animal?',
#        'answers': [{'answer_start': 30, 'text': 'rats'}]}],
#      'context': 'Wistar-Han and Sprague-Dawley rats'},
#     {'qas': [{'id': '5e6d1c6f1af46fc130000021_001',
#        'question': 'Han Wistar and Sprague Dawley are breeds of what laboratory animal?',
#        'answers': [{'answer_start': 30, 'text': 'rats'}]}],
#      'context': 'Wistar Han and Sprague-Dawley Rats.'},
#     {'qas': [{'id': '5e6d1c6f1af46fc130000021_002',
# ...

# %%
# aa = json.load(open('/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/mediqa/mediqa.json'))

# %%
# import random
# random.seed(42)
# indices_train = random.sample(list(range(len(aa))), int(len(aa)*.80))
# indices_test  = list(set(list(range(len(aa))))-set(indices_train))

# %%
# import re
# mediqa = list(aa.values())
# train = [mediqa[i] for i in indices_train]
# test  = [mediqa[i] for i in indices_test]

# # re.sub(' +', ' ', aa['1_Answer8']['summary'])

# %%
# # 37 nafee
# 109.41 + 146.40

# %%
# for x in train:
#   context = re.sub(' +', ' ', x['articles'])
#   context = re.sub('\.\.+', '', context)
#   context = re.sub(' +', ' ', context)
#   answer = re.sub(' +', ' ', x['summary'])
#   answer = re.sub('\.\.+', '', answer)
#   answer = re.sub(' +', ' ', answer)

#   print(answer)
#   print(context)
#   break
  
#   question = re.sub(' +', ' ', x['question'])
#   idx = re.sub(' +', ' ', x['question_id'])

# %%
k = 0
para = []
for x in quac_test['data']:
  if len(x['paragraphs'][0]['qas']) != 1:
    print('BLAAA')
  answer = x['paragraphs'][0]['qas'][0]['answers']
  if answer:
#     print(x['paragraphs'][0]['context'].find(answer[0]['text']))
    k+=1
    context = x['paragraphs'][0]['context']
    question = x['paragraphs'][0]['qas'][0]['question']
    ids = x['paragraphs'][0]['qas'][0]['id']
    para.append({'qas': [{'id': ids,
                          'question': question,
                          'answers': answer}],
                 'context': context})

k
# Out:
# 5868

# %%
squad_json={
          "data": [
            {
              "paragraphs":para,
               "title":f'quac'
            }],
           "version":0
       }  

out_path = '/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/quac/'
with open(out_path+f'test_quac.json', "w") as writer:
    writer.write(json.dumps(squad_json, indent=4) + "\n")

# %%
(emrqa_test['data'][0]['paragraphs'])
# Out:
# [{'context': "RECORD #808959 022039090 | UGH | 34853160 | | 4624027 | 7/5/2005 12:00:00 AM | RULE OUT MYCOCARDIAL INFARCTION | Signed | DIS | Admission Date: 4/17/2005 Report Status: Signed Discharge Date: 10/6/2005 ATTENDING: WEISSMANN, RORY M.D. DATE OF SURGERY: 2/11/05. HISTORY AND PHYSICAL: This is a 74-year-old gentleman with a history on insulin-dependent diabetes mellitus, hypertension, coronary artery disease, with substernal chest pain on exertion, which had been increasing for the month prior to surgery. He denies any shortness of breath, PND or orthopnea. He has a history of three-vessel disease on catheterization back in 1996, status post angioplasty without stenting. He reportedly had an abnormal exercise tolerance test in 1996 and in 1999. He was admitted via his primary care physician's office on 6/13/05 with substernal chest pain and T wave inversions in leads V3 and V4. Enzymes were cycled and they were negative x4. The patient went to the cath on 0/18/05 and was fou
# ...

# %%
k = 0
para = []
for x in emrqa_test['data']:
    k+=1
    context = x['paragraphs'][0]['context']
    for y in x['paragraphs'][0]['qas']:
      answer = y['answers']
      answer_start = y['answers'][0]['answer_start']
      answer_text = y['answers'][0]['text']
      if answer_text == context[answer_start:answer_start+len(answer_text)]:
        question = y['question']
        ids = y['id']
        para.append({'qas': [{'id': ids,
                              'question': question,
                              'answers': answer}],
                     'context': context})

k
# Out:
# 53

# %%
len(para)
# Out:
# 44517

# %%
quac_test['data'][0]['paragraphs'][0]['qas'][0]['answers'][0]['text']
# Out:
# 'In May 1983, she married Nikos Karvelas, a composer,'

# %%
fact_data = [x for x in bioasq_test['questions'] if x['type']=='factoid']

para = []

for x in fact_data:
  question = x['body']
  answer = x['exact_answer'][0][0]
  idx = x['id']
  for i,y in enumerate(x['snippets']):
    context = y['text']
    ids = idx+f'_{i:03d}'
    answer_start = context.lower().find(answer.lower())
    if answer_start != -1:
      para.append({'qas': [{'id': ids,
                            'question': question,
                            'answers': [{'answer_start': answer_start, 'text': answer}]}],
                   'context': context})

# %%
len(para)
# Out:
# 937

# %%
# squad_json={
#           "data": [
#             {
#               "paragraphs":para,
#                "title":f'bioasq9b'
#             }],
#            "version":0
#        }  

# out_path = '/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/bioasq/'
# with open(out_path+f'test_bioasq9b.json', "w") as writer:
#     writer.write(json.dumps(squad_json, indent=4) + "\n")

# %%
print(squad_test['data'][20]['paragraphs'][0]['qas']
     )
# Out:
# [{'answers': [{'answer_start': 49, 'text': 'the arid plains of Central Asia'}, {'answer_start': 68, 'text': 'Central Asia'}, {'answer_start': 68, 'text': 'Central Asia'}], 'question': 'Where did the black death originate?', 'id': '57264684708984140094c123'}, {'answers': [{'answer_start': 270, 'text': 'merchant ships.'}, {'answer_start': 270, 'text': 'merchant ships'}, {'answer_start': 116, 'text': 'Silk Road'}], 'question': 'How did the black death make it to the Mediterranean and Europe?', 'id': '57264684708984140094c124'}, {'answers': [{'answer_start': 381, 'text': "30–60% of Europe's total population"}, {'answer_start': 381, 'text': "30–60% of Europe's total population"}, {'answer_start': 381, 'text': '30–60%'}], 'question': 'How much of the European population did the black death kill?', 'id': '57264684708984140094c125'}, {'answers': [{'answer_start': 618, 'text': 'the 17th century'}, {'answer_start': 622, 'text': '17th century'}, {'answer_start': 622, 'text': '17th century'}], '
# ...

# %%
# x = bioasq_train['data'][0]['paragraphs']
# k=0
# labeled_9b = []
# for b in x:
#   if b['qas'][0]['question']!='[MASK]':
#     k+=1
#     labeled_9b.append(b)

# %%
# k==len(labeled_9b), k, labeled_9b[2000]

# %%
# bioasq_json={
#           "data": [
#             {
#               "paragraphs":labeled_9b,
#                "title":f'labeled_9b'
#             }],
#            "version":0
#        }  

# out_path = Path('/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/bioasq/')
# with open(out_path/f'train_bioasq9b.json', "w") as writer:
#     writer.write(json.dumps(bioasq_json, indent=4) + "\n")
