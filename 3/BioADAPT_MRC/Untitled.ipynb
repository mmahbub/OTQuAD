# %%
# !python3 load_dataset.py  \
    --orig_model_name_or_path bioelectra  \
    --model_name_or_path kamalkraj/bioelectra-base-discriminator-pubmed-pmc-lt  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/  \
    --train_file train_emrqa_risk.json \
    --dataset_name emrqa_risk  \
    --do_lower_case \
    --do_train \
    --max_seq_length 384  \
    --doc_stride 128  \
    --overwrite_cache
# Out:
# /net/kdinxidk03/opt/NFS/75y/data/qa/output/cached_train_bioelectra_384_train_emrqa_risk
# ...
# add example index and unique id: 100%|███████| 83/83 [00:00<00:00, 26147.46it/s]

# %%
# path = '/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/bioasq/test_bioasq_9B.json'
# golden_path = '/net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/bioasq/Task9BGoldenEnriched/9B_golden.json'
# data = json.load(open(path))
# golden_data = json.load(open(golden_path))

# %%
# data['data'][0]['paragraphs']

# %%
# (golden_data['questions'][0]['snippets'])

# %%
# question = golden_data['questions'][0]['body']
# q_type   = golden_data['questions'][0]['type']
# answer   = golden_data['questions'][0]['exact_answer']

# %%
# golden_data['questions'][1]

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0, 1, 2"  # specify which GPU(s) to be used

# %%
# !python3 finetune_model.py  \
    --model_type electra \
    --orig_model_name_or_path bioelectra  \
    --model_name_or_path kamalkraj/bioelectra-base-discriminator-pubmed-pmc-lt  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/REVISION/REVIEWER-2/emrqa/risk-squad/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/squad/  \
    --train_file train-squad.json  \
    --dataset_name squad  \
    --do_train \
    --n_gpu=3 \
    --per_gpu_train_batch_size=16 \
    --do_lower_case \
    --learning_rate=5e-5 \
    --num_train_epochs=3.0 \
    --max_seq_length 384  \
    --doc_stride 128  \
    --overwrite_output_dir  \
    --overwrite_output_model_dir
# Out:
# 05/05/2022 12:38:06 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 3, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-05-05 12:38:06,197 >> loading configuration file https://huggingface.co/kamalkraj/bioelectra-base-discriminator-pubmed-pmc-lt/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/88411c2090a65d361112c116aef49469b33a9109e75a232047da473252ba0df3.989ea6bb133ac3e40b912f5a641d3e582c4f013acbc1fcc539e8891331385cbb
# [INFO|configuration_utils.py:566] 2022-05-05 12:38:06,199 >> Model config ElectraConfig {
#   "architectures": [
#     "ElectraForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
# ...

# %%
# !python3 finetune_model.py  \
    --model_type electra \
    --orig_model_name_or_path bioelectra  \
    --model_name_or_path kamalkraj/bioelectra-base-discriminator-pubmed-pmc-lt  \
    --output_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/ \
    --output_model_dir /net/kdinxidk03/opt/NFS/75y/data/qa/output/REVISION/REVIEWER-2/emrqa/risk/ \
    --data_dir /net/kdinxidk03/opt/NFS/75y/data/qa/dataset_pos/emrqa/datasets/  \
    --train_file risk-dataset-train_70perc.json \
    --dataset_name emrqa_risk_seed10  \
    --do_lower_case \
    --do_train \
    --n_gpu=3 \
    --per_gpu_eval_batch_size=256 \
    --max_seq_length 384  \
    --doc_stride 128  \
    --overwrite_output_dir  \
# Out:
# 05/05/2022 19:27:03 - WARNING - __main__ - Process rank: -1, device: cuda, n_gpu: 3, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:530] 2022-05-05 19:27:03,225 >> loading configuration file https://huggingface.co/kamalkraj/bioelectra-base-discriminator-pubmed-pmc-lt/resolve/main/config.json from cache at /net/kdinxidk03/opt/NFS/huggingface_cache/transformers/88411c2090a65d361112c116aef49469b33a9109e75a232047da473252ba0df3.989ea6bb133ac3e40b912f5a641d3e582c4f013acbc1fcc539e8891331385cbb
# [INFO|configuration_utils.py:566] 2022-05-05 19:27:03,226 >> Model config ElectraConfig {
#   "architectures": [
#     "ElectraForPreTraining"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
# ...
